# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

net = Net().to(device)
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (conv4_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#   (conv5_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.5)
#   (fc1): Linear(in_features=18432, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   (fc3): Linear(in_features=2048, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])


# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 32

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints'].to(device)

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor).to(device)

        # forward pass to get net output
        output_pts = net.eval()(images)  # net.eval() turns off regularization 
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images.cpu(), output_pts.cpu(), key_pts.cpu()

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='r')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        image = image.cpu().numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.cpu().numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

# criterion = nn.MSELoss()

criterion = nn.SmoothL1Loss()

# optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)

optimizer = optim.Adam(net.parameters(), lr = 1e-4, betas=(0.9, 0.999), eps=1e-08)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
# Calculate accuracy so that we can compare different models/lossFunctions
def accuracy_mse(test_outputs, gt_pts):
    # move to cpu and convert back to np array
    predicted_key_pts = test_outputs.data.cpu().numpy()
    gt_key_points = gt_pts.data.cpu().numpy()
    
    se_sum = 0.0
    for idx in range(predicted_key_pts.shape[0]):
        res_x = predicted_key_pts[idx][ : , 0] - gt_key_points[idx][ : , 0]
        res_y = predicted_key_pts[idx][ : , 1] - gt_key_points[idx][ : , 1]
        se = np.sum(res_x ** 2) + np.sum(res_y ** 2)
        se_sum += se
        
    mse = se_sum / (predicted_key_pts.shape[1] * predicted_key_pts.shape[2]) # divide by 132
    return mse

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        nn.init.xavier_uniform_(m.weight.data)
        # nn.init.xavier_uniform(m.bias.data)
        
def train_net(n_epochs):

    # prepare the net for training
    net.train()
    net.apply(weights_init) # Gaussian init

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        print("Running on device : ", device)
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            

            # forward pass to get outputs
            output_pts = net(images.to(device))
            

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts.to(device))

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()
            if batch_i % 100 == 99:    # print every 50 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(epoch + 1, batch_i+1, running_loss/1000))
                running_loss = 0.0

    print('Finished Training')
    
    # Get accuracy by running another non-updating epoch
    mse = 0.0
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            
            # forward pass to get outputs
            output_pts = net(images.to(device))
            
            # reshape to batch_size x 68 x 2 pts
            output_pts = output_pts.view(output_pts.size()[0], 68, -1)
            key_pts = key_pts.view(output_pts.size()[0], 68, -1)
            
            mse += accuracy_mse(output_pts, key_pts)

    print('\nTraining Accuracy (MSE): ', mse/(batch_i+1))

# %%
# train your network
n_epochs = 1000 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# Running on device :  cuda
# Epoch: 1, Batch: 100, Avg. Loss: 0.010357759505510331
# Running on device :  cuda
# Epoch: 2, Batch: 100, Avg. Loss: 0.006490307953208685
# Running on device :  cuda
# Epoch: 3, Batch: 100, Avg. Loss: 0.0051179097183048725
# Running on device :  cuda
# Epoch: 4, Batch: 100, Avg. Loss: 0.005010521152988077
# Running on device :  cuda
# Epoch: 5, Batch: 100, Avg. Loss: 0.004687651354819536
# Running on device :  cuda
# Epoch: 6, Batch: 100, Avg. Loss: 0.004391028532758355
# Running on device :  cuda
# Epoch: 7, Batch: 100, Avg. Loss: 0.004084162175655365
# Running on device :  cuda
# Epoch: 8, Batch: 100, Avg. Loss: 0.0039349518176168205
# Running on device :  cuda
# Epoch: 9, Batch: 100, Avg. Loss: 0.0035978776793926955
# Running on device :  cuda
# Epoch: 10, Batch: 100, Avg. Loss: 0.0034699173774570225
# Running on device :  cuda
# Epoch: 11, Batch: 100, Avg. Loss: 0.0034294634219259024
# Running on device :  cuda
# Epoch: 12, Batch: 100, Avg. Loss: 0.0030662575121968984
# Running on device :  cuda
# Epoch: 13, Batch: 100, Avg. Loss: 0.003163747714832425
# Running on device :  cuda
# Epoch: 14, Batch: 100, Avg. Loss: 0.002919920485466719
# Running on device :  cuda
# Epoch: 15, Batch: 100, Avg. Loss: 0.003031391942873597
# Running on device :  cuda
# Epoch: 16, Batch: 100, Avg. Loss: 0.0031572873201221228
# Running on device :  cuda
# Epoch: 17, Batch: 100, Avg. Loss: 0.0029550190828740597
# Running on device :  cuda
# Epoch: 18, Batch: 100, Avg. Loss: 0.002992985177785158
# Running on device :  cuda
# Epoch: 19, Batch: 100, Avg. Loss: 0.0029472849145531655
# Running on device :  cuda
# Epoch: 20, Batch: 100, Avg. Loss: 0.002854442734271288
# Running on device :  cuda
# Epoch: 21, Batch: 100, Avg. Loss: 0.003032132975757122
# Running on device :  cuda
# Epoch: 22, Batch: 100, Avg. Loss: 0.002836953626945615
# Running on device :  cuda
# Epoch: 23, Batch: 100, Avg. Loss: 0.0028285884130746126
# Running on device :  cuda
# Epoch: 24, Batch: 100, Avg. Loss: 0.002769592251628637
# Running on device :  cuda
# Epoch: 25, Batch: 100, Avg. Loss: 0.0028978366367518904
# Running on device :  cuda
# Epoch: 26, Batch: 100, Avg. Loss: 0.002956770906224847
# Running on device :  cuda
# Epoch: 27, Batch: 100, Avg. Loss: 0.0027378995548933745
# Running on device :  cuda
# Epoch: 28, Batch: 100, Avg. Loss: 0.0027229293435811998
# Running on device :  cuda
# Epoch: 29, Batch: 100, Avg. Loss: 0.0026625349335372447
# Running on device :  cuda
# Epoch: 30, Batch: 100, Avg. Loss: 0.002684916103258729
# Running on device :  cuda
# Epoch: 31, Batch: 100, Avg. Loss: 0.0028391534481197597
# Running on device :  cuda
# Epoch: 32, Batch: 100, Avg. Loss: 0.0026471831928938628
# Running on device :  cuda
# Epoch: 33, Batch: 100, Avg. Loss: 0.0025137091483920814
# Running on device :  cuda
# Epoch: 34, Batch: 100, Avg. Loss: 0.0025204469840973617
# Running on device :  cuda
# Epoch: 35, Batch: 100, Avg. Loss: 0.0025316462414339187
# Running on device :  cuda
# Epoch: 36, Batch: 100, Avg. Loss: 0.002496652473695576
# Running on device :  cuda
# Epoch: 37, Batch: 100, Avg. Loss: 0.002788503176532686
# Running on device :  cuda
# Epoch: 38, Batch: 100, Avg. Loss: 0.00263689870107919
# Running on device :  cuda
# Epoch: 39, Batch: 100, Avg. Loss: 0.002600037993863225
# Running on device :  cuda
# Epoch: 40, Batch: 100, Avg. Loss: 0.002889467759989202
# Running on device :  cuda
# Epoch: 41, Batch: 100, Avg. Loss: 0.0025651755770668386
# Running on device :  cuda
# Epoch: 42, Batch: 100, Avg. Loss: 0.0027016102988272907
# Running on device :  cuda
# Epoch: 43, Batch: 100, Avg. Loss: 0.0027372504137456416
# Running on device :  cuda
# Epoch: 44, Batch: 100, Avg. Loss: 0.002705916501581669
# Running on device :  cuda
# Epoch: 45, Batch: 100, Avg. Loss: 0.002470013770274818
# Running on device :  cuda
# Epoch: 46, Batch: 100, Avg. Loss: 0.0025631922110915186
# Running on device :  cuda
# Epoch: 47, Batch: 100, Avg. Loss: 0.002564312316477299
# Running on device :  cuda
# Epoch: 48, Batch: 100, Avg. Loss: 0.0026119772624224424
# Running on device :  cuda
# Epoch: 49, Batch: 100, Avg. Loss: 0.002631286014802754
# Running on device :  cuda
# Epoch: 50, Batch: 100, Avg. Loss: 0.002624832607805729
# Running on device :  cuda
# Epoch: 51, Batch: 100, Avg. Loss: 0.002524205536581576
# Running on device :  cuda
# Epoch: 52, Batch: 100, Avg. Loss: 0.0024689482264220715
# Running on device :  cuda
# Epoch: 53, Batch: 100, Avg. Loss: 0.0025444254633039238
# Running on device :  cuda
# Epoch: 54, Batch: 100, Avg. Loss: 0.0025388791086152196
# Running on device :  cuda
# Epoch: 55, Batch: 100, Avg. Loss: 0.0025344419600442053
# Running on device :  cuda
# Epoch: 56, Batch: 100, Avg. Loss: 0.002566311287693679
# Running on device :  cuda
# Epoch: 57, Batch: 100, Avg. Loss: 0.00244072591047734
# Running on device :  cuda
# Epoch: 58, Batch: 100, Avg. Loss: 0.002363066703081131
# Running on device :  cuda
# Epoch: 59, Batch: 100, Avg. Loss: 0.002621915552765131
# Running on device :  cuda
# Epoch: 60, Batch: 100, Avg. Loss: 0.0024638397060334685
# Running on device :  cuda
# Epoch: 61, Batch: 100, Avg. Loss: 0.0023061163146048786
# Running on device :  cuda
# Epoch: 62, Batch: 100, Avg. Loss: 0.002465973465703428
# Running on device :  cuda
# Epoch: 63, Batch: 100, Avg. Loss: 0.00237754971627146
# Running on device :  cuda
# Epoch: 64, Batch: 100, Avg. Loss: 0.00238357444293797
# Running on device :  cuda
# Epoch: 65, Batch: 100, Avg. Loss: 0.0024334985977038743
# Running on device :  cuda
# Epoch: 66, Batch: 100, Avg. Loss: 0.0023435795605182648
# Running on device :  cuda
# Epoch: 67, Batch: 100, Avg. Loss: 0.002234712588600814
# Running on device :  cuda
# Epoch: 68, Batch: 100, Avg. Loss: 0.002284853641875088
# Running on device :  cuda
# Epoch: 69, Batch: 100, Avg. Loss: 0.0023040973925963046
# Running on device :  cuda
# Epoch: 70, Batch: 100, Avg. Loss: 0.002378251784481108
# Running on device :  cuda
# Epoch: 71, Batch: 100, Avg. Loss: 0.0022366530131548643
# Running on device :  cuda
# Epoch: 72, Batch: 100, Avg. Loss: 0.0023710260670632122
# Running on device :  cuda
# Epoch: 73, Batch: 100, Avg. Loss: 0.002491719645448029
# Running on device :  cuda
# Epoch: 74, Batch: 100, Avg. Loss: 0.0023169633196666838
# Running on device :  cuda
# Epoch: 75, Batch: 100, Avg. Loss: 0.0022217389577999713
# Running on device :  cuda
# Epoch: 76, Batch: 100, Avg. Loss: 0.0022656418969854712
# Running on device :  cuda
# Epoch: 77, Batch: 100, Avg. Loss: 0.0022414179984480143
# Running on device :  cuda
# Epoch: 78, Batch: 100, Avg. Loss: 0.002251932030543685
# Running on device :  cuda
# Epoch: 79, Batch: 100, Avg. Loss: 0.002197557603009045
# Running on device :  cuda
# Epoch: 80, Batch: 100, Avg. Loss: 0.0024104151856154206
# Running on device :  cuda
# Epoch: 81, Batch: 100, Avg. Loss: 0.002276631376706064
# Running on device :  cuda
# Epoch: 82, Batch: 100, Avg. Loss: 0.002248576929792762
# Running on device :  cuda
# Epoch: 83, Batch: 100, Avg. Loss: 0.0023096928438171745
# Running on device :  cuda
# Epoch: 84, Batch: 100, Avg. Loss: 0.002365655631758273
# Running on device :  cuda
# Epoch: 85, Batch: 100, Avg. Loss: 0.002382725422270596
# Running on device :  cuda
# Epoch: 86, Batch: 100, Avg. Loss: 0.002283960892818868
# Running on device :  cuda
# Epoch: 87, Batch: 100, Avg. Loss: 0.0021774008991196753
# Running on device :  cuda
# Epoch: 88, Batch: 100, Avg. Loss: 0.0024202135233208537
# Running on device :  cuda
# Epoch: 89, Batch: 100, Avg. Loss: 0.00239911216404289
# Running on device :  cuda
# Epoch: 90, Batch: 100, Avg. Loss: 0.0021711694886907937
# Running on device :  cuda
# Epoch: 91, Batch: 100, Avg. Loss: 0.002153979208320379
# Running on device :  cuda
# Epoch: 92, Batch: 100, Avg. Loss: 0.0022383309258148074
# Running on device :  cuda
# Epoch: 93, Batch: 100, Avg. Loss: 0.0022312962161377074
# Running on device :  cuda
# Epoch: 94, Batch: 100, Avg. Loss: 0.002109261492267251
# Running on device :  cuda
# Epoch: 95, Batch: 100, Avg. Loss: 0.002170971226878464
# Running on device :  cuda
# Epoch: 96, Batch: 100, Avg. Loss: 0.0021048667738214136
# Running on device :  cuda
# Epoch: 97, Batch: 100, Avg. Loss: 0.002146723636426032
# Running on device :  cuda
# Epoch: 98, Batch: 100, Avg. Loss: 0.002193557858467102
# Running on device :  cuda
# Epoch: 99, Batch: 100, Avg. Loss: 0.002236224568448961
# Running on device :  cuda
# Epoch: 100, Batch: 100, Avg. Loss: 0.0022583490507677197
# Running on device :  cuda
# Epoch: 101, Batch: 100, Avg. Loss: 0.0022702610334381463
# Running on device :  cuda
# Epoch: 102, Batch: 100, Avg. Loss: 0.002129129771143198
# Running on device :  cuda
# Epoch: 103, Batch: 100, Avg. Loss: 0.0022027296191081407
# Running on device :  cuda
# Epoch: 104, Batch: 100, Avg. Loss: 0.002142381718382239
# Running on device :  cuda
# Epoch: 105, Batch: 100, Avg. Loss: 0.002328296396881342
# Running on device :  cuda
# Epoch: 106, Batch: 100, Avg. Loss: 0.0021531419968232515
# Running on device :  cuda
# Epoch: 107, Batch: 100, Avg. Loss: 0.002047214599326253
# Running on device :  cuda
# Epoch: 108, Batch: 100, Avg. Loss: 0.002141465375199914
# Running on device :  cuda
# Epoch: 109, Batch: 100, Avg. Loss: 0.0023075110809877516
# Running on device :  cuda
# Epoch: 110, Batch: 100, Avg. Loss: 0.002149375271052122
# Running on device :  cuda
# Epoch: 111, Batch: 100, Avg. Loss: 0.0019776062415912746
# Running on device :  cuda
# Epoch: 112, Batch: 100, Avg. Loss: 0.0021046680444851518
# Running on device :  cuda
# Epoch: 113, Batch: 100, Avg. Loss: 0.0022821548292413355
# Running on device :  cuda
# Epoch: 114, Batch: 100, Avg. Loss: 0.002179724001325667
# Running on device :  cuda
# Epoch: 115, Batch: 100, Avg. Loss: 0.0020658903559669854
# Running on device :  cuda
# Epoch: 116, Batch: 100, Avg. Loss: 0.002177695489488542
# Running on device :  cuda
# Epoch: 117, Batch: 100, Avg. Loss: 0.0020935619305819273
# Running on device :  cuda
# Epoch: 118, Batch: 100, Avg. Loss: 0.0020921807177364826
# Running on device :  cuda
# Epoch: 119, Batch: 100, Avg. Loss: 0.002097244621254504
# Running on device :  cuda
# Epoch: 120, Batch: 100, Avg. Loss: 0.002068946155719459
# Running on device :  cuda
# Epoch: 121, Batch: 100, Avg. Loss: 0.002303932661190629
# Running on device :  cuda
# Epoch: 122, Batch: 100, Avg. Loss: 0.002186189765110612
# Running on device :  cuda
# Epoch: 123, Batch: 100, Avg. Loss: 0.002103896708227694
# Running on device :  cuda
# Epoch: 124, Batch: 100, Avg. Loss: 0.002189626168459654
# Running on device :  cuda
# Epoch: 125, Batch: 100, Avg. Loss: 0.002069131481461227
# Running on device :  cuda
# Epoch: 126, Batch: 100, Avg. Loss: 0.002092954592779279
# Running on device :  cuda
# Epoch: 127, Batch: 100, Avg. Loss: 0.0021562375500798225
# Running on device :  cuda
# Epoch: 128, Batch: 100, Avg. Loss: 0.0020955278631299736
# Running on device :  cuda
# Epoch: 129, Batch: 100, Avg. Loss: 0.0019421993726864456
# Running on device :  cuda
# Epoch: 130, Batch: 100, Avg. Loss: 0.0023089173221960664
# Running on device :  cuda
# Epoch: 131, Batch: 100, Avg. Loss: 0.002007332564331591
# Running on device :  cuda
# Epoch: 132, Batch: 100, Avg. Loss: 0.002159131751395762
# Running on device :  cuda
# Epoch: 133, Batch: 100, Avg. Loss: 0.0021762008145451545
# Running on device :  cuda
# Epoch: 134, Batch: 100, Avg. Loss: 0.0020506183924153447
# Running on device :  cuda
# Epoch: 135, Batch: 100, Avg. Loss: 0.0019641265850514175
# Running on device :  cuda
# Epoch: 136, Batch: 100, Avg. Loss: 0.002066660859622061
# Running on device :  cuda
# Epoch: 137, Batch: 100, Avg. Loss: 0.0019661575928330423
# Running on device :  cuda
# Epoch: 138, Batch: 100, Avg. Loss: 0.0020495240483433008
# Running on device :  cuda
# Epoch: 139, Batch: 100, Avg. Loss: 0.0019423826579004525
# Running on device :  cuda
# Epoch: 140, Batch: 100, Avg. Loss: 0.0019612391320988536
# Running on device :  cuda
# Epoch: 141, Batch: 100, Avg. Loss: 0.002118302320130169
# Running on device :  cuda
# Epoch: 142, Batch: 100, Avg. Loss: 0.0018942839736118913
# Running on device :  cuda
# Epoch: 143, Batch: 100, Avg. Loss: 0.002078277382068336
# Running on device :  cuda
# Epoch: 144, Batch: 100, Avg. Loss: 0.002040639573708177
# Running on device :  cuda
# Epoch: 145, Batch: 100, Avg. Loss: 0.0020037748822942375
# Running on device :  cuda
# Epoch: 146, Batch: 100, Avg. Loss: 0.0021038230769336226
# Running on device :  cuda
# Epoch: 147, Batch: 100, Avg. Loss: 0.0022245241487398744
# Running on device :  cuda
# Epoch: 148, Batch: 100, Avg. Loss: 0.0020667531928047537
# Running on device :  cuda
# Epoch: 149, Batch: 100, Avg. Loss: 0.0020033484920859335
# Running on device :  cuda
# Epoch: 150, Batch: 100, Avg. Loss: 0.002000543177127838
# Running on device :  cuda
# Epoch: 151, Batch: 100, Avg. Loss: 0.001976597568951547
# Running on device :  cuda
# Epoch: 152, Batch: 100, Avg. Loss: 0.002099086089991033
# Running on device :  cuda
# Epoch: 153, Batch: 100, Avg. Loss: 0.0019228368066251278
# Running on device :  cuda
# Epoch: 154, Batch: 100, Avg. Loss: 0.0019515821263194084
# Running on device :  cuda
# Epoch: 155, Batch: 100, Avg. Loss: 0.001943094233982265
# Running on device :  cuda
# Epoch: 156, Batch: 100, Avg. Loss: 0.0018930641179904341
# Running on device :  cuda
# Epoch: 157, Batch: 100, Avg. Loss: 0.0019596613524481654
# Running on device :  cuda
# Epoch: 158, Batch: 100, Avg. Loss: 0.001923624492250383
# Running on device :  cuda
# Epoch: 159, Batch: 100, Avg. Loss: 0.0019440758936107158
# Running on device :  cuda
# Epoch: 160, Batch: 100, Avg. Loss: 0.0018957350300624967
# Running on device :  cuda
# Epoch: 161, Batch: 100, Avg. Loss: 0.0019611973613500597
# Running on device :  cuda
# Epoch: 162, Batch: 100, Avg. Loss: 0.001777693004347384
# Running on device :  cuda
# Epoch: 163, Batch: 100, Avg. Loss: 0.0019712456641718746
# Running on device :  cuda
# Epoch: 164, Batch: 100, Avg. Loss: 0.001917221039533615
# Running on device :  cuda
# Epoch: 165, Batch: 100, Avg. Loss: 0.0018715993454679848
# Running on device :  cuda
# Epoch: 166, Batch: 100, Avg. Loss: 0.0019227124201133847
# Running on device :  cuda
# Epoch: 167, Batch: 100, Avg. Loss: 0.0018965031867846846
# Running on device :  cuda
# Epoch: 168, Batch: 100, Avg. Loss: 0.001840868660248816
# Running on device :  cuda
# Epoch: 169, Batch: 100, Avg. Loss: 0.0019504066603258253
# Running on device :  cuda
# Epoch: 170, Batch: 100, Avg. Loss: 0.0019195916084572672
# Running on device :  cuda
# Epoch: 171, Batch: 100, Avg. Loss: 0.0018460912378504871
# Running on device :  cuda
# Epoch: 172, Batch: 100, Avg. Loss: 0.00192199173476547
# Running on device :  cuda
# Epoch: 173, Batch: 100, Avg. Loss: 0.001971065222285688
# Running on device :  cuda
# Epoch: 174, Batch: 100, Avg. Loss: 0.001908199562691152
# Running on device :  cuda
# Epoch: 175, Batch: 100, Avg. Loss: 0.0018975108740851283
# Running on device :  cuda
# Epoch: 176, Batch: 100, Avg. Loss: 0.0020070132287219166
# Running on device :  cuda
# Epoch: 177, Batch: 100, Avg. Loss: 0.0019817155627533793
# Running on device :  cuda
# Epoch: 178, Batch: 100, Avg. Loss: 0.0019288433799520134
# Running on device :  cuda
# Epoch: 179, Batch: 100, Avg. Loss: 0.0019491874584928156
# Running on device :  cuda
# Epoch: 180, Batch: 100, Avg. Loss: 0.0018270551385357976
# Running on device :  cuda
# Epoch: 181, Batch: 100, Avg. Loss: 0.0017705918941646815
# Running on device :  cuda
# Epoch: 182, Batch: 100, Avg. Loss: 0.001818344053812325
# Running on device :  cuda
# Epoch: 183, Batch: 100, Avg. Loss: 0.001962123701348901
# Running on device :  cuda
# Epoch: 184, Batch: 100, Avg. Loss: 0.001821659010834992
# Running on device :  cuda
# Epoch: 185, Batch: 100, Avg. Loss: 0.0017038552742451429
# Running on device :  cuda
# Epoch: 186, Batch: 100, Avg. Loss: 0.0017372950110584498
# Running on device :  cuda
# Epoch: 187, Batch: 100, Avg. Loss: 0.0017886594356969
# Running on device :  cuda
# Epoch: 188, Batch: 100, Avg. Loss: 0.0018754806043580175
# Running on device :  cuda
# Epoch: 189, Batch: 100, Avg. Loss: 0.0018092250982299446
# Running on device :  cuda
# Epoch: 190, Batch: 100, Avg. Loss: 0.0018708571074530483
# Running on device :  cuda
# Epoch: 191, Batch: 100, Avg. Loss: 0.0018095250725746156
# Running on device :  cuda
# Epoch: 192, Batch: 100, Avg. Loss: 0.0017579968553036451
# Running on device :  cuda
# Epoch: 193, Batch: 100, Avg. Loss: 0.001852808663621545
# Running on device :  cuda
# Epoch: 194, Batch: 100, Avg. Loss: 0.0017624837802723051
# Running on device :  cuda
# Epoch: 195, Batch: 100, Avg. Loss: 0.0017190971979871392
# Running on device :  cuda
# Epoch: 196, Batch: 100, Avg. Loss: 0.001777761934325099
# Running on device :  cuda
# Epoch: 197, Batch: 100, Avg. Loss: 0.001763955065049231
# Running on device :  cuda
# Epoch: 198, Batch: 100, Avg. Loss: 0.0019100706819444894
# Running on device :  cuda
# Epoch: 199, Batch: 100, Avg. Loss: 0.0018362510036677123
# Running on device :  cuda
# Epoch: 200, Batch: 100, Avg. Loss: 0.0017516304049640893
# Running on device :  cuda
# Epoch: 201, Batch: 100, Avg. Loss: 0.0017238648403435945
# Running on device :  cuda
# Epoch: 202, Batch: 100, Avg. Loss: 0.001829589798115194
# Running on device :  cuda
# Epoch: 203, Batch: 100, Avg. Loss: 0.0018299549603834747
# Running on device :  cuda
# Epoch: 204, Batch: 100, Avg. Loss: 0.0018153923572972416
# Running on device :  cuda
# Epoch: 205, Batch: 100, Avg. Loss: 0.0017353987665846944
# Running on device :  cuda
# Epoch: 206, Batch: 100, Avg. Loss: 0.0017134572817012667
# Running on device :  cuda
# Epoch: 207, Batch: 100, Avg. Loss: 0.001735518777742982
# Running on device :  cuda
# Epoch: 208, Batch: 100, Avg. Loss: 0.0016861730590462685
# Running on device :  cuda
# Epoch: 209, Batch: 100, Avg. Loss: 0.0017957400856539608
# Running on device :  cuda
# Epoch: 210, Batch: 100, Avg. Loss: 0.0016877122987061738
# Running on device :  cuda
# Epoch: 211, Batch: 100, Avg. Loss: 0.0017368229627609253
# Running on device :  cuda
# Epoch: 212, Batch: 100, Avg. Loss: 0.001648876253515482
# Running on device :  cuda
# Epoch: 213, Batch: 100, Avg. Loss: 0.0017221846887841821
# Running on device :  cuda
# Epoch: 214, Batch: 100, Avg. Loss: 0.0016915580369532108
# Running on device :  cuda
# Epoch: 215, Batch: 100, Avg. Loss: 0.0017039595386013388
# Running on device :  cuda
# Epoch: 216, Batch: 100, Avg. Loss: 0.0017913360400125383
# Running on device :  cuda
# Epoch: 217, Batch: 100, Avg. Loss: 0.0016624689707532526
# Running on device :  cuda
# Epoch: 218, Batch: 100, Avg. Loss: 0.001645777326077223
# Running on device :  cuda
# Epoch: 219, Batch: 100, Avg. Loss: 0.0015895256837829947
# Running on device :  cuda
# Epoch: 220, Batch: 100, Avg. Loss: 0.0016589034842327238
# Running on device :  cuda
# Epoch: 221, Batch: 100, Avg. Loss: 0.0017781689139083029
# Running on device :  cuda
# Epoch: 222, Batch: 100, Avg. Loss: 0.0017320355204865337
# Running on device :  cuda
# Epoch: 223, Batch: 100, Avg. Loss: 0.0017524036653339863
# Running on device :  cuda
# Epoch: 224, Batch: 100, Avg. Loss: 0.001749446756206453
# Running on device :  cuda
# Epoch: 225, Batch: 100, Avg. Loss: 0.0017445535375736653
# Running on device :  cuda
# Epoch: 226, Batch: 100, Avg. Loss: 0.001776974869892001
# Running on device :  cuda
# Epoch: 227, Batch: 100, Avg. Loss: 0.001642044992186129
# Running on device :  cuda
# Epoch: 228, Batch: 100, Avg. Loss: 0.0016892423313111067
# Running on device :  cuda
# Epoch: 229, Batch: 100, Avg. Loss: 0.0017058573700487615
# Running on device :  cuda
# Epoch: 230, Batch: 100, Avg. Loss: 0.0015497554382309317
# Running on device :  cuda
# Epoch: 231, Batch: 100, Avg. Loss: 0.0016113121518865228
# Running on device :  cuda
# Epoch: 232, Batch: 100, Avg. Loss: 0.0015171179585158825
# Running on device :  cuda
# Epoch: 233, Batch: 100, Avg. Loss: 0.001609383938834071
# Running on device :  cuda
# Epoch: 234, Batch: 100, Avg. Loss: 0.0015446001086384057
# Running on device :  cuda
# Epoch: 235, Batch: 100, Avg. Loss: 0.0015988386357203125
# Running on device :  cuda
# Epoch: 236, Batch: 100, Avg. Loss: 0.001564763544127345
# Running on device :  cuda
# Epoch: 237, Batch: 100, Avg. Loss: 0.001554663496091962
# Running on device :  cuda
# Epoch: 238, Batch: 100, Avg. Loss: 0.001666588069871068
# Running on device :  cuda
# Epoch: 239, Batch: 100, Avg. Loss: 0.0015781971402466298
# Running on device :  cuda
# Epoch: 240, Batch: 100, Avg. Loss: 0.001446672186255455
# Running on device :  cuda
# Epoch: 241, Batch: 100, Avg. Loss: 0.0015644241776317357
# Running on device :  cuda
# Epoch: 242, Batch: 100, Avg. Loss: 0.001692247553728521
# Running on device :  cuda
# Epoch: 243, Batch: 100, Avg. Loss: 0.0015283585218712687
# Running on device :  cuda
# Epoch: 244, Batch: 100, Avg. Loss: 0.001506142593920231
# Running on device :  cuda
# Epoch: 245, Batch: 100, Avg. Loss: 0.001585985204204917
# Running on device :  cuda
# Epoch: 246, Batch: 100, Avg. Loss: 0.0016611223481595517
# Running on device :  cuda
# Epoch: 247, Batch: 100, Avg. Loss: 0.0015703700510784984
# Running on device :  cuda
# Epoch: 248, Batch: 100, Avg. Loss: 0.0016389429168775678
# Running on device :  cuda
# Epoch: 249, Batch: 100, Avg. Loss: 0.001628566924482584
# Running on device :  cuda
# Epoch: 250, Batch: 100, Avg. Loss: 0.001575867211446166
# Running on device :  cuda
# Epoch: 251, Batch: 100, Avg. Loss: 0.0014988556643947958
# Running on device :  cuda
# Epoch: 252, Batch: 100, Avg. Loss: 0.0015032780459150671
# Running on device :  cuda
# Epoch: 253, Batch: 100, Avg. Loss: 0.001613081251271069
# Running on device :  cuda
# Epoch: 254, Batch: 100, Avg. Loss: 0.0015333820218220353
# Running on device :  cuda
# Epoch: 255, Batch: 100, Avg. Loss: 0.0016256765956059098
# Running on device :  cuda
# Epoch: 256, Batch: 100, Avg. Loss: 0.0016084931241348386
# Running on device :  cuda
# Epoch: 257, Batch: 100, Avg. Loss: 0.001531261240132153
# Running on device :  cuda
# Epoch: 258, Batch: 100, Avg. Loss: 0.0015153971835970878
# Running on device :  cuda
# Epoch: 259, Batch: 100, Avg. Loss: 0.001569332861341536
# Running on device :  cuda
# Epoch: 260, Batch: 100, Avg. Loss: 0.0013687005145475268
# Running on device :  cuda
# Epoch: 261, Batch: 100, Avg. Loss: 0.0015141175286844373
# Running on device :  cuda
# Epoch: 262, Batch: 100, Avg. Loss: 0.0015543100656941534
# Running on device :  cuda
# Epoch: 263, Batch: 100, Avg. Loss: 0.001571807616390288
# Running on device :  cuda
# Epoch: 264, Batch: 100, Avg. Loss: 0.0015154209891334177
# Running on device :  cuda
# Epoch: 265, Batch: 100, Avg. Loss: 0.001467512311413884
# Running on device :  cuda
# Epoch: 266, Batch: 100, Avg. Loss: 0.0015263405069708823
# Running on device :  cuda
# Epoch: 267, Batch: 100, Avg. Loss: 0.0015281588630750775
# Running on device :  cuda
# Epoch: 268, Batch: 100, Avg. Loss: 0.001431362010538578
# Running on device :  cuda
# Epoch: 269, Batch: 100, Avg. Loss: 0.0015065150009468198
# Running on device :  cuda
# Epoch: 270, Batch: 100, Avg. Loss: 0.0014786156956106424
# Running on device :  cuda
# Epoch: 271, Batch: 100, Avg. Loss: 0.0014040463380515576
# Running on device :  cuda
# Epoch: 272, Batch: 100, Avg. Loss: 0.0014715708326548337
# Running on device :  cuda
# Epoch: 273, Batch: 100, Avg. Loss: 0.0015064472407102585
# Running on device :  cuda
# Epoch: 274, Batch: 100, Avg. Loss: 0.0015623087771236897
# Running on device :  cuda
# Epoch: 275, Batch: 100, Avg. Loss: 0.001486879956908524
# Running on device :  cuda
# Epoch: 276, Batch: 100, Avg. Loss: 0.0015364919267594815
# Running on device :  cuda
# Epoch: 277, Batch: 100, Avg. Loss: 0.0014883764190599322
# Running on device :  cuda
# Epoch: 278, Batch: 100, Avg. Loss: 0.0014549630573019385
# Running on device :  cuda
# Epoch: 279, Batch: 100, Avg. Loss: 0.0014247433329001068
# Running on device :  cuda
# Epoch: 280, Batch: 100, Avg. Loss: 0.001478863375261426
# Running on device :  cuda
# Epoch: 281, Batch: 100, Avg. Loss: 0.0015025481302291155
# Running on device :  cuda
# Epoch: 282, Batch: 100, Avg. Loss: 0.0015079998886212706
# Running on device :  cuda
# Epoch: 283, Batch: 100, Avg. Loss: 0.001520158803090453
# Running on device :  cuda
# Epoch: 284, Batch: 100, Avg. Loss: 0.001378550094552338
# Running on device :  cuda
# Epoch: 285, Batch: 100, Avg. Loss: 0.001401268866378814
# Running on device :  cuda
# Epoch: 286, Batch: 100, Avg. Loss: 0.0014349524825811387
# Running on device :  cuda
# Epoch: 287, Batch: 100, Avg. Loss: 0.0013778573768213392
# Running on device :  cuda
# Epoch: 288, Batch: 100, Avg. Loss: 0.0014046024857088924
# Running on device :  cuda
# Epoch: 289, Batch: 100, Avg. Loss: 0.0014156159535050393
# Running on device :  cuda
# Epoch: 290, Batch: 100, Avg. Loss: 0.0013177659143693745
# Running on device :  cuda
# Epoch: 291, Batch: 100, Avg. Loss: 0.0013018101174384355
# Running on device :  cuda
# Epoch: 292, Batch: 100, Avg. Loss: 0.0014083863059058785
# Running on device :  cuda
# Epoch: 293, Batch: 100, Avg. Loss: 0.0013220424838364124
# Running on device :  cuda
# Epoch: 294, Batch: 100, Avg. Loss: 0.0013182355277240277
# Running on device :  cuda
# Epoch: 295, Batch: 100, Avg. Loss: 0.0013821675255894662
# Running on device :  cuda
# Epoch: 296, Batch: 100, Avg. Loss: 0.0013768356167711319
# Running on device :  cuda
# Epoch: 297, Batch: 100, Avg. Loss: 0.0013373317159712315
# Running on device :  cuda
# Epoch: 298, Batch: 100, Avg. Loss: 0.0013899789350107312
# Running on device :  cuda
# Epoch: 299, Batch: 100, Avg. Loss: 0.0012573137087747454
# Running on device :  cuda
# Epoch: 300, Batch: 100, Avg. Loss: 0.001493505827151239
# Running on device :  cuda
# Epoch: 301, Batch: 100, Avg. Loss: 0.0013918257839977742
# Running on device :  cuda
# Epoch: 302, Batch: 100, Avg. Loss: 0.0012947060680016875
# Running on device :  cuda
# Epoch: 303, Batch: 100, Avg. Loss: 0.0014896748466417193
# Running on device :  cuda
# Epoch: 304, Batch: 100, Avg. Loss: 0.0012793604037724434
# Running on device :  cuda
# Epoch: 305, Batch: 100, Avg. Loss: 0.001228046966716647
# Running on device :  cuda
# Epoch: 306, Batch: 100, Avg. Loss: 0.0013318277704529465
# Running on device :  cuda
# Epoch: 307, Batch: 100, Avg. Loss: 0.0013222680715844035
# Running on device :  cuda
# Epoch: 308, Batch: 100, Avg. Loss: 0.0014124425360932946
# Running on device :  cuda
# Epoch: 309, Batch: 100, Avg. Loss: 0.0013265599887818098
# Running on device :  cuda
# Epoch: 310, Batch: 100, Avg. Loss: 0.0013695504809729754
# Running on device :  cuda
# Epoch: 311, Batch: 100, Avg. Loss: 0.001283227143343538
# Running on device :  cuda
# Epoch: 312, Batch: 100, Avg. Loss: 0.0012083193925209344
# Running on device :  cuda
# Epoch: 313, Batch: 100, Avg. Loss: 0.0012804681826382876
# Running on device :  cuda
# Epoch: 314, Batch: 100, Avg. Loss: 0.001330689737573266
# Running on device :  cuda
# Epoch: 315, Batch: 100, Avg. Loss: 0.0013056331342086195
# Running on device :  cuda
# Epoch: 316, Batch: 100, Avg. Loss: 0.001394203926436603
# Running on device :  cuda
# Epoch: 317, Batch: 100, Avg. Loss: 0.0013554833820089698
# Running on device :  cuda
# Epoch: 318, Batch: 100, Avg. Loss: 0.0013025612435303628
# Running on device :  cuda
# Epoch: 319, Batch: 100, Avg. Loss: 0.001342068602796644
# Running on device :  cuda
# Epoch: 320, Batch: 100, Avg. Loss: 0.0012746404097415506
# Running on device :  cuda
# Epoch: 321, Batch: 100, Avg. Loss: 0.0011957355695776642
# Running on device :  cuda
# Epoch: 322, Batch: 100, Avg. Loss: 0.0014068928714841605
# Running on device :  cuda
# Epoch: 323, Batch: 100, Avg. Loss: 0.001282658803742379
# Running on device :  cuda
# Epoch: 324, Batch: 100, Avg. Loss: 0.0014059067331254483
# Running on device :  cuda
# Epoch: 325, Batch: 100, Avg. Loss: 0.0012595831537619232
# Running on device :  cuda
# Epoch: 326, Batch: 100, Avg. Loss: 0.0011893322002142668
# Running on device :  cuda
# Epoch: 327, Batch: 100, Avg. Loss: 0.0012402970981784166
# Running on device :  cuda
# Epoch: 328, Batch: 100, Avg. Loss: 0.0013004400441423058
# Running on device :  cuda
# Epoch: 329, Batch: 100, Avg. Loss: 0.001306563670746982
# Running on device :  cuda
# Epoch: 330, Batch: 100, Avg. Loss: 0.0012462392654269934
# Running on device :  cuda
# Epoch: 331, Batch: 100, Avg. Loss: 0.001310570938512683
# Running on device :  cuda
# Epoch: 332, Batch: 100, Avg. Loss: 0.00124451523181051
# Running on device :  cuda
# Epoch: 333, Batch: 100, Avg. Loss: 0.0012744423663243651
# Running on device :  cuda
# Epoch: 334, Batch: 100, Avg. Loss: 0.001226823420729488
# Running on device :  cuda
# Epoch: 335, Batch: 100, Avg. Loss: 0.0012656479524448515
# Running on device :  cuda
# Epoch: 336, Batch: 100, Avg. Loss: 0.0012792898425832392
# Running on device :  cuda
# Epoch: 337, Batch: 100, Avg. Loss: 0.0012457619388587774
# Running on device :  cuda
# Epoch: 338, Batch: 100, Avg. Loss: 0.0011495048389770092
# Running on device :  cuda
# Epoch: 339, Batch: 100, Avg. Loss: 0.001233196673449129
# Running on device :  cuda
# Epoch: 340, Batch: 100, Avg. Loss: 0.0011977106165140868
# Running on device :  cuda
# Epoch: 341, Batch: 100, Avg. Loss: 0.0012457733196206391
# Running on device :  cuda
# Epoch: 342, Batch: 100, Avg. Loss: 0.001195293778553605
# Running on device :  cuda
# Epoch: 343, Batch: 100, Avg. Loss: 0.0013735881671309471
# Running on device :  cuda
# Epoch: 344, Batch: 100, Avg. Loss: 0.0012237637555226684
# Running on device :  cuda
# Epoch: 345, Batch: 100, Avg. Loss: 0.001302081615664065
# Running on device :  cuda
# Epoch: 346, Batch: 100, Avg. Loss: 0.001258179172873497
# Running on device :  cuda
# Epoch: 347, Batch: 100, Avg. Loss: 0.0011535988575778902
# Running on device :  cuda
# Epoch: 348, Batch: 100, Avg. Loss: 0.0011235043476335704
# Running on device :  cuda
# Epoch: 349, Batch: 100, Avg. Loss: 0.0012864846587181092
# Running on device :  cuda
# Epoch: 350, Batch: 100, Avg. Loss: 0.0013189707081764936
# Running on device :  cuda
# Epoch: 351, Batch: 100, Avg. Loss: 0.0012162840971723199
# Running on device :  cuda
# Epoch: 352, Batch: 100, Avg. Loss: 0.0011183179644867777
# Running on device :  cuda
# Epoch: 353, Batch: 100, Avg. Loss: 0.0012333634588867425
# Running on device :  cuda
# Epoch: 354, Batch: 100, Avg. Loss: 0.0011787158171646297
# Running on device :  cuda
# Epoch: 355, Batch: 100, Avg. Loss: 0.0012372470092959702
# Running on device :  cuda
# Epoch: 356, Batch: 100, Avg. Loss: 0.0012142678676173092
# Running on device :  cuda
# Epoch: 357, Batch: 100, Avg. Loss: 0.0011874650623649359
# Running on device :  cuda
# Epoch: 358, Batch: 100, Avg. Loss: 0.0011512929438613356
# Running on device :  cuda
# Epoch: 359, Batch: 100, Avg. Loss: 0.001250359105411917
# Running on device :  cuda
# Epoch: 360, Batch: 100, Avg. Loss: 0.001265633231960237
# Running on device :  cuda
# Epoch: 361, Batch: 100, Avg. Loss: 0.0012591547663323582
# Running on device :  cuda
# Epoch: 362, Batch: 100, Avg. Loss: 0.0010965586574748158
# Running on device :  cuda
# Epoch: 363, Batch: 100, Avg. Loss: 0.0010875261849723756
# Running on device :  cuda
# Epoch: 364, Batch: 100, Avg. Loss: 0.001170208822004497
# Running on device :  cuda
# Epoch: 365, Batch: 100, Avg. Loss: 0.0011329446202144027
# Running on device :  cuda
# Epoch: 366, Batch: 100, Avg. Loss: 0.0012258494161069393
# Running on device :  cuda
# Epoch: 367, Batch: 100, Avg. Loss: 0.0011519706286489963
# Running on device :  cuda
# Epoch: 368, Batch: 100, Avg. Loss: 0.0011774758049286902
# Running on device :  cuda
# Epoch: 369, Batch: 100, Avg. Loss: 0.0011578264813870193
# Running on device :  cuda
# Epoch: 370, Batch: 100, Avg. Loss: 0.0011434036577120422
# Running on device :  cuda
# Epoch: 371, Batch: 100, Avg. Loss: 0.0011462770998477937
# Running on device :  cuda
# Epoch: 372, Batch: 100, Avg. Loss: 0.0012027958948165178
# Running on device :  cuda
# Epoch: 373, Batch: 100, Avg. Loss: 0.0011520882402546704
# Running on device :  cuda
# Epoch: 374, Batch: 100, Avg. Loss: 0.0010973226451314985
# Running on device :  cuda
# Epoch: 375, Batch: 100, Avg. Loss: 0.0011306404676288367
# Running on device :  cuda
# Epoch: 376, Batch: 100, Avg. Loss: 0.0011983673693612218
# Running on device :  cuda
# Epoch: 377, Batch: 100, Avg. Loss: 0.0010758427395485342
# Running on device :  cuda
# Epoch: 378, Batch: 100, Avg. Loss: 0.0011851921919733286
# Running on device :  cuda
# Epoch: 379, Batch: 100, Avg. Loss: 0.0012067902525886892
# Running on device :  cuda
# Epoch: 380, Batch: 100, Avg. Loss: 0.001085282134823501
# Running on device :  cuda
# Epoch: 381, Batch: 100, Avg. Loss: 0.0011060359510593116
# Running on device :  cuda
# Epoch: 382, Batch: 100, Avg. Loss: 0.001219479376450181
# Running on device :  cuda
# Epoch: 383, Batch: 100, Avg. Loss: 0.001103714203927666
# Running on device :  cuda
# Epoch: 384, Batch: 100, Avg. Loss: 0.0010768142151646317
# Running on device :  cuda
# Epoch: 385, Batch: 100, Avg. Loss: 0.00122034031432122
# Running on device :  cuda
# Epoch: 386, Batch: 100, Avg. Loss: 0.001073581969831139
# Running on device :  cuda
# Epoch: 387, Batch: 100, Avg. Loss: 0.001185820048674941
# Running on device :  cuda
# Epoch: 388, Batch: 100, Avg. Loss: 0.001181238149292767
# Running on device :  cuda
# Epoch: 389, Batch: 100, Avg. Loss: 0.0011660286248661577
# Running on device :  cuda
# Epoch: 390, Batch: 100, Avg. Loss: 0.0012929767649620771
# Running on device :  cuda
# Epoch: 391, Batch: 100, Avg. Loss: 0.0010722810216248035
# Running on device :  cuda
# Epoch: 392, Batch: 100, Avg. Loss: 0.0011737778093665837
# Running on device :  cuda
# Epoch: 393, Batch: 100, Avg. Loss: 0.0010492155239917337
# Running on device :  cuda
# Epoch: 394, Batch: 100, Avg. Loss: 0.0012087359069846571
# Running on device :  cuda
# Epoch: 395, Batch: 100, Avg. Loss: 0.001005003768019378
# Running on device :  cuda
# Epoch: 396, Batch: 100, Avg. Loss: 0.0010772456964477897
# Running on device :  cuda
# Epoch: 397, Batch: 100, Avg. Loss: 0.0011266139899380504
# Running on device :  cuda
# Epoch: 398, Batch: 100, Avg. Loss: 0.0010851088869385421
# Running on device :  cuda
# Epoch: 399, Batch: 100, Avg. Loss: 0.0010768584101460874
# Running on device :  cuda
# Epoch: 400, Batch: 100, Avg. Loss: 0.0010594643908552826
# Running on device :  cuda
# Epoch: 401, Batch: 100, Avg. Loss: 0.0011159736099652946
# Running on device :  cuda
# Epoch: 402, Batch: 100, Avg. Loss: 0.0010089698894880713
# Running on device :  cuda
# Epoch: 403, Batch: 100, Avg. Loss: 0.0010435880292207003
# Running on device :  cuda
# Epoch: 404, Batch: 100, Avg. Loss: 0.001084139434620738
# Running on device :  cuda
# Epoch: 405, Batch: 100, Avg. Loss: 0.001025759586598724
# Running on device :  cuda
# Epoch: 406, Batch: 100, Avg. Loss: 0.0010353413019329309
# Running on device :  cuda
# Epoch: 407, Batch: 100, Avg. Loss: 0.0010562832807190716
# Running on device :  cuda
# Epoch: 408, Batch: 100, Avg. Loss: 0.0011444742642343045
# Running on device :  cuda
# Epoch: 409, Batch: 100, Avg. Loss: 0.0012388209900818766
# Running on device :  cuda
# Epoch: 410, Batch: 100, Avg. Loss: 0.0011885088211856783
# Running on device :  cuda
# Epoch: 411, Batch: 100, Avg. Loss: 0.0009796238536946475
# Running on device :  cuda
# Epoch: 412, Batch: 100, Avg. Loss: 0.0010332247861661017
# Running on device :  cuda
# Epoch: 413, Batch: 100, Avg. Loss: 0.001084338926244527
# Running on device :  cuda
# Epoch: 414, Batch: 100, Avg. Loss: 0.0011682612616568803
# Running on device :  cuda
# Epoch: 415, Batch: 100, Avg. Loss: 0.0010512146297842265
# Running on device :  cuda
# Epoch: 416, Batch: 100, Avg. Loss: 0.0009591193832457066
# Running on device :  cuda
# Epoch: 417, Batch: 100, Avg. Loss: 0.0010288818017579616
# Running on device :  cuda
# Epoch: 418, Batch: 100, Avg. Loss: 0.0010322441044263542
# Running on device :  cuda
# Epoch: 419, Batch: 100, Avg. Loss: 0.0011172404019162059
# Running on device :  cuda
# Epoch: 420, Batch: 100, Avg. Loss: 0.0010108298808336259
# Running on device :  cuda
# Epoch: 421, Batch: 100, Avg. Loss: 0.001018536050338298
# Running on device :  cuda
# Epoch: 422, Batch: 100, Avg. Loss: 0.001107272118795663
# Running on device :  cuda
# Epoch: 423, Batch: 100, Avg. Loss: 0.0009783144844695926
# Running on device :  cuda
# Epoch: 424, Batch: 100, Avg. Loss: 0.0009711664589121938
# Running on device :  cuda
# Epoch: 425, Batch: 100, Avg. Loss: 0.0010264375070109964
# Running on device :  cuda
# Epoch: 426, Batch: 100, Avg. Loss: 0.0011187497042119503
# Running on device :  cuda
# Epoch: 427, Batch: 100, Avg. Loss: 0.0010520426062867046
# Running on device :  cuda
# Epoch: 428, Batch: 100, Avg. Loss: 0.001127885782159865
# Running on device :  cuda
# Epoch: 429, Batch: 100, Avg. Loss: 0.001018509297631681
# Running on device :  cuda
# Epoch: 430, Batch: 100, Avg. Loss: 0.0010448723593726754
# Running on device :  cuda
# Epoch: 431, Batch: 100, Avg. Loss: 0.0010723235802724957
# Running on device :  cuda
# Epoch: 432, Batch: 100, Avg. Loss: 0.000994438745547086
# Running on device :  cuda
# Epoch: 433, Batch: 100, Avg. Loss: 0.0010722586046904325
# Running on device :  cuda
# Epoch: 434, Batch: 100, Avg. Loss: 0.000968127551022917
# Running on device :  cuda
# Epoch: 435, Batch: 100, Avg. Loss: 0.0010894379555247723
# Running on device :  cuda
# Epoch: 436, Batch: 100, Avg. Loss: 0.0010019209231249989
# Running on device :  cuda
# Epoch: 437, Batch: 100, Avg. Loss: 0.0010418294556438924
# Running on device :  cuda
# Epoch: 438, Batch: 100, Avg. Loss: 0.0009443895695731044
# Running on device :  cuda
# Epoch: 439, Batch: 100, Avg. Loss: 0.0011018023476935923
# Running on device :  cuda
# Epoch: 440, Batch: 100, Avg. Loss: 0.0010562413586303592
# Running on device :  cuda
# Epoch: 441, Batch: 100, Avg. Loss: 0.0009907226637005807
# Running on device :  cuda
# Epoch: 442, Batch: 100, Avg. Loss: 0.0009261863804422319
# Running on device :  cuda
# Epoch: 443, Batch: 100, Avg. Loss: 0.0010617408477701248
# Running on device :  cuda
# Epoch: 444, Batch: 100, Avg. Loss: 0.0009418796151876449
# Running on device :  cuda
# Epoch: 445, Batch: 100, Avg. Loss: 0.001063824207521975
# Running on device :  cuda
# Epoch: 446, Batch: 100, Avg. Loss: 0.0010368802300654352
# Running on device :  cuda
# Epoch: 447, Batch: 100, Avg. Loss: 0.0010327310934662819
# Running on device :  cuda
# Epoch: 448, Batch: 100, Avg. Loss: 0.001041757924016565
# Running on device :  cuda
# Epoch: 449, Batch: 100, Avg. Loss: 0.0010017620236612856
# Running on device :  cuda
# Epoch: 450, Batch: 100, Avg. Loss: 0.001021858589258045
# Running on device :  cuda
# Epoch: 451, Batch: 100, Avg. Loss: 0.0010004409970715642
# Running on device :  cuda
# Epoch: 452, Batch: 100, Avg. Loss: 0.0010244693476706742
# Running on device :  cuda
# Epoch: 453, Batch: 100, Avg. Loss: 0.0009360032090917229
# Running on device :  cuda
# Epoch: 454, Batch: 100, Avg. Loss: 0.0010218411521054804
# Running on device :  cuda
# Epoch: 455, Batch: 100, Avg. Loss: 0.0009885065900161862
# Running on device :  cuda
# Epoch: 456, Batch: 100, Avg. Loss: 0.0009301427938044071
# Running on device :  cuda
# Epoch: 457, Batch: 100, Avg. Loss: 0.0009974304409697651
# Running on device :  cuda
# Epoch: 458, Batch: 100, Avg. Loss: 0.0009098709048703312
# Running on device :  cuda
# Epoch: 459, Batch: 100, Avg. Loss: 0.000949220621958375
# Running on device :  cuda
# Epoch: 460, Batch: 100, Avg. Loss: 0.001065461211372167
# Running on device :  cuda
# Epoch: 461, Batch: 100, Avg. Loss: 0.0009116610186174511
# Running on device :  cuda
# Epoch: 462, Batch: 100, Avg. Loss: 0.0009558106157928706
# Running on device :  cuda
# Epoch: 463, Batch: 100, Avg. Loss: 0.000983067695517093
# Running on device :  cuda
# Epoch: 464, Batch: 100, Avg. Loss: 0.000892016134224832
# Running on device :  cuda
# Epoch: 465, Batch: 100, Avg. Loss: 0.0009360990854911506
# Running on device :  cuda
# Epoch: 466, Batch: 100, Avg. Loss: 0.0009181076781824231
# Running on device :  cuda
# Epoch: 467, Batch: 100, Avg. Loss: 0.0010057951672933995
# Running on device :  cuda
# Epoch: 468, Batch: 100, Avg. Loss: 0.0009444827390834689
# Running on device :  cuda
# Epoch: 469, Batch: 100, Avg. Loss: 0.0009193128519691527
# Running on device :  cuda
# Epoch: 470, Batch: 100, Avg. Loss: 0.000977315969299525
# Running on device :  cuda
# Epoch: 471, Batch: 100, Avg. Loss: 0.0009706748123280704
# Running on device :  cuda
# Epoch: 472, Batch: 100, Avg. Loss: 0.0009750900464132428
# Running on device :  cuda
# Epoch: 473, Batch: 100, Avg. Loss: 0.0009713449203409255
# Running on device :  cuda
# Epoch: 474, Batch: 100, Avg. Loss: 0.0009103808971121908
# Running on device :  cuda
# Epoch: 475, Batch: 100, Avg. Loss: 0.0009242962640710175
# Running on device :  cuda
# Epoch: 476, Batch: 100, Avg. Loss: 0.000903108088299632
# Running on device :  cuda
# Epoch: 477, Batch: 100, Avg. Loss: 0.0009391706776805222
# Running on device :  cuda
# Epoch: 478, Batch: 100, Avg. Loss: 0.000867051262408495
# Running on device :  cuda
# Epoch: 479, Batch: 100, Avg. Loss: 0.0009982500118203461
# Running on device :  cuda
# Epoch: 480, Batch: 100, Avg. Loss: 0.0009189388304948807
# Running on device :  cuda
# Epoch: 481, Batch: 100, Avg. Loss: 0.0008629507250152528
# Running on device :  cuda
# Epoch: 482, Batch: 100, Avg. Loss: 0.0009549026931636035
# Running on device :  cuda
# Epoch: 483, Batch: 100, Avg. Loss: 0.0009562821420840919
# Running on device :  cuda
# Epoch: 484, Batch: 100, Avg. Loss: 0.0008567876103334128
# Running on device :  cuda
# Epoch: 485, Batch: 100, Avg. Loss: 0.000931078381370753
# Running on device :  cuda
# Epoch: 486, Batch: 100, Avg. Loss: 0.0009753501969389617
# Running on device :  cuda
# Epoch: 487, Batch: 100, Avg. Loss: 0.0009348345519974828
# Running on device :  cuda
# Epoch: 488, Batch: 100, Avg. Loss: 0.0008878751089796424
# Running on device :  cuda
# Epoch: 489, Batch: 100, Avg. Loss: 0.0009328422080725432
# Running on device :  cuda
# Epoch: 490, Batch: 100, Avg. Loss: 0.0009011743701994419
# Running on device :  cuda
# Epoch: 491, Batch: 100, Avg. Loss: 0.0009324029888957739
# Running on device :  cuda
# Epoch: 492, Batch: 100, Avg. Loss: 0.0008807298550382257
# Running on device :  cuda
# Epoch: 493, Batch: 100, Avg. Loss: 0.00089961361233145
# Running on device :  cuda
# Epoch: 494, Batch: 100, Avg. Loss: 0.0008542286446318031
# Running on device :  cuda
# Epoch: 495, Batch: 100, Avg. Loss: 0.0008998199761845172
# Running on device :  cuda
# Epoch: 496, Batch: 100, Avg. Loss: 0.0008822146099992097
# Running on device :  cuda
# Epoch: 497, Batch: 100, Avg. Loss: 0.0008511508628726006
# Running on device :  cuda
# Epoch: 498, Batch: 100, Avg. Loss: 0.0009206007178872823
# Running on device :  cuda
# Epoch: 499, Batch: 100, Avg. Loss: 0.0010252754613757134
# Running on device :  cuda
# Epoch: 500, Batch: 100, Avg. Loss: 0.0009081305041909218
# Running on device :  cuda
# Epoch: 501, Batch: 100, Avg. Loss: 0.0008791135321371258
# Running on device :  cuda
# Epoch: 502, Batch: 100, Avg. Loss: 0.0009738614982925355
# Running on device :  cuda
# Epoch: 503, Batch: 100, Avg. Loss: 0.0009403108390979469
# Running on device :  cuda
# Epoch: 504, Batch: 100, Avg. Loss: 0.0008934140806086361
# Running on device :  cuda
# Epoch: 505, Batch: 100, Avg. Loss: 0.0008815347040072083
# Running on device :  cuda
# Epoch: 506, Batch: 100, Avg. Loss: 0.0008390636118128895
# Running on device :  cuda
# Epoch: 507, Batch: 100, Avg. Loss: 0.0008625270742923021
# Running on device :  cuda
# Epoch: 508, Batch: 100, Avg. Loss: 0.0008827525894157588
# Running on device :  cuda
# Epoch: 509, Batch: 100, Avg. Loss: 0.0009474895163439214
# Running on device :  cuda
# Epoch: 510, Batch: 100, Avg. Loss: 0.0008993850094266236
# Running on device :  cuda
# Epoch: 511, Batch: 100, Avg. Loss: 0.0008840846377424896
# Running on device :  cuda
# Epoch: 512, Batch: 100, Avg. Loss: 0.0008934331126511097
# Running on device :  cuda
# Epoch: 513, Batch: 100, Avg. Loss: 0.0009849029802717268
# Running on device :  cuda
# Epoch: 514, Batch: 100, Avg. Loss: 0.0009032224961556494
# Running on device :  cuda
# Epoch: 515, Batch: 100, Avg. Loss: 0.0009007811564952135
# Running on device :  cuda
# Epoch: 516, Batch: 100, Avg. Loss: 0.0009485616888850927
# Running on device :  cuda
# Epoch: 517, Batch: 100, Avg. Loss: 0.0008625976331532001
# Running on device :  cuda
# Epoch: 518, Batch: 100, Avg. Loss: 0.000838256074115634
# Running on device :  cuda
# Epoch: 519, Batch: 100, Avg. Loss: 0.000968017631676048
# Running on device :  cuda
# Epoch: 520, Batch: 100, Avg. Loss: 0.0008837850773707033
# Running on device :  cuda
# Epoch: 521, Batch: 100, Avg. Loss: 0.000835853482130915
# Running on device :  cuda
# Epoch: 522, Batch: 100, Avg. Loss: 0.0008256257553584873
# Running on device :  cuda
# Epoch: 523, Batch: 100, Avg. Loss: 0.0008153901090845466
# Running on device :  cuda
# Epoch: 524, Batch: 100, Avg. Loss: 0.0008507685507647693
# Running on device :  cuda
# Epoch: 525, Batch: 100, Avg. Loss: 0.0008750105327926576
# Running on device :  cuda
# Epoch: 526, Batch: 100, Avg. Loss: 0.0008838813630864024
# Running on device :  cuda
# Epoch: 527, Batch: 100, Avg. Loss: 0.000784949014429003
# Running on device :  cuda
# Epoch: 528, Batch: 100, Avg. Loss: 0.0009457163494080305
# Running on device :  cuda
# Epoch: 529, Batch: 100, Avg. Loss: 0.0009446199978701771
# Running on device :  cuda
# Epoch: 530, Batch: 100, Avg. Loss: 0.0008609561258926988
# Running on device :  cuda
# Epoch: 531, Batch: 100, Avg. Loss: 0.0007773665259592235
# Running on device :  cuda
# Epoch: 532, Batch: 100, Avg. Loss: 0.0009313073097728193
# Running on device :  cuda
# Epoch: 533, Batch: 100, Avg. Loss: 0.0008371409163810313
# Running on device :  cuda
# Epoch: 534, Batch: 100, Avg. Loss: 0.0008276420985348522
# Running on device :  cuda
# Epoch: 535, Batch: 100, Avg. Loss: 0.0009427517945878208
# Running on device :  cuda
# Epoch: 536, Batch: 100, Avg. Loss: 0.0008993274639360607
# Running on device :  cuda
# Epoch: 537, Batch: 100, Avg. Loss: 0.0008374702553264797
# Running on device :  cuda
# Epoch: 538, Batch: 100, Avg. Loss: 0.0008378487639129162
# Running on device :  cuda
# Epoch: 539, Batch: 100, Avg. Loss: 0.0008514514775015414
# Running on device :  cuda
# Epoch: 540, Batch: 100, Avg. Loss: 0.0007899401476606727
# Running on device :  cuda
# Epoch: 541, Batch: 100, Avg. Loss: 0.0008780819335952401
# Running on device :  cuda
# Epoch: 542, Batch: 100, Avg. Loss: 0.0008220797604881228
# Running on device :  cuda
# Epoch: 543, Batch: 100, Avg. Loss: 0.0008513460936956107
# Running on device :  cuda
# Epoch: 544, Batch: 100, Avg. Loss: 0.0008408196154050529
# Running on device :  cuda
# Epoch: 545, Batch: 100, Avg. Loss: 0.0008221804932691157
# Running on device :  cuda
# Epoch: 546, Batch: 100, Avg. Loss: 0.0008072097557596862
# Running on device :  cuda
# Epoch: 547, Batch: 100, Avg. Loss: 0.0008086860394105316
# Running on device :  cuda
# Epoch: 548, Batch: 100, Avg. Loss: 0.0008275164319202304
# Running on device :  cuda
# Epoch: 549, Batch: 100, Avg. Loss: 0.0008421730697154999
# Running on device :  cuda
# Epoch: 550, Batch: 100, Avg. Loss: 0.0008383080456405878
# Running on device :  cuda
# Epoch: 551, Batch: 100, Avg. Loss: 0.0008494943329133093
# Running on device :  cuda
# Epoch: 552, Batch: 100, Avg. Loss: 0.0007814173293299973
# Running on device :  cuda
# Epoch: 553, Batch: 100, Avg. Loss: 0.0008183551267720759
# Running on device :  cuda
# Epoch: 554, Batch: 100, Avg. Loss: 0.0008071302785538137
# Running on device :  cuda
# Epoch: 555, Batch: 100, Avg. Loss: 0.0008498186860233546
# Running on device :  cuda
# Epoch: 556, Batch: 100, Avg. Loss: 0.0008511296641081572
# Running on device :  cuda
# Epoch: 557, Batch: 100, Avg. Loss: 0.0008085264642722905
# Running on device :  cuda
# Epoch: 558, Batch: 100, Avg. Loss: 0.0008010970442555845
# Running on device :  cuda
# Epoch: 559, Batch: 100, Avg. Loss: 0.0008170112683437764
# Running on device :  cuda
# Epoch: 560, Batch: 100, Avg. Loss: 0.0007823069505393505
# Running on device :  cuda
# Epoch: 561, Batch: 100, Avg. Loss: 0.0008092664526775479
# Running on device :  cuda
# Epoch: 562, Batch: 100, Avg. Loss: 0.0007762699821032584
# Running on device :  cuda
# Epoch: 563, Batch: 100, Avg. Loss: 0.00080586599977687
# Running on device :  cuda
# Epoch: 564, Batch: 100, Avg. Loss: 0.0008427798612974584
# Running on device :  cuda
# Epoch: 565, Batch: 100, Avg. Loss: 0.0008852512077428401
# Running on device :  cuda
# Epoch: 566, Batch: 100, Avg. Loss: 0.0007988435649313033
# Running on device :  cuda
# Epoch: 567, Batch: 100, Avg. Loss: 0.0007852109060622752
# Running on device :  cuda
# Epoch: 568, Batch: 100, Avg. Loss: 0.0008028869954869151
# Running on device :  cuda
# Epoch: 569, Batch: 100, Avg. Loss: 0.0007756408848799766
# Running on device :  cuda
# Epoch: 570, Batch: 100, Avg. Loss: 0.0007915955791249871
# Running on device :  cuda
# Epoch: 571, Batch: 100, Avg. Loss: 0.0008019009637646377
# Running on device :  cuda
# Epoch: 572, Batch: 100, Avg. Loss: 0.0007868616073392332
# Running on device :  cuda
# Epoch: 573, Batch: 100, Avg. Loss: 0.0008248995221219957
# Running on device :  cuda
# Epoch: 574, Batch: 100, Avg. Loss: 0.0007568187885917723
# Running on device :  cuda
# Epoch: 575, Batch: 100, Avg. Loss: 0.0007578539666719734
# Running on device :  cuda
# Epoch: 576, Batch: 100, Avg. Loss: 0.0007856156420893968
# Running on device :  cuda
# Epoch: 577, Batch: 100, Avg. Loss: 0.0007974527878686785
# Running on device :  cuda
# Epoch: 578, Batch: 100, Avg. Loss: 0.0007444006791338325
# Running on device :  cuda
# Epoch: 579, Batch: 100, Avg. Loss: 0.0008763473886065185
# Running on device :  cuda
# Epoch: 580, Batch: 100, Avg. Loss: 0.0007423682701773941
# Running on device :  cuda
# Epoch: 581, Batch: 100, Avg. Loss: 0.0007506708204746246
# Running on device :  cuda
# ...
# Running on device :  cuda
# Epoch: 809, Batch: 100, Avg. Loss: 0.0006396565646864474
# Running on device :  cuda
# Epoch: 810, Batch: 100, Avg. Loss: 0.0006359757995232939
# Running on device :  cuda
# Epoch: 811, Batch: 100, Avg. Loss: 0.0005960950995795429
# Running on device :  cuda
# Epoch: 812, Batch: 100, Avg. Loss: 0.000623711938271299
# Running on device :  cuda
# Epoch: 813, Batch: 100, Avg. Loss: 0.0006080355376470834
# Running on device :  cuda
# Epoch: 814, Batch: 100, Avg. Loss: 0.000615875378716737
# Running on device :  cuda
# Epoch: 815, Batch: 100, Avg. Loss: 0.0006041185953654349
# Running on device :  cuda
# Epoch: 816, Batch: 100, Avg. Loss: 0.0006235503160860389
# Running on device :  cuda
# Epoch: 817, Batch: 100, Avg. Loss: 0.0005836763286497443
# Running on device :  cuda
# Epoch: 818, Batch: 100, Avg. Loss: 0.0005494453620631248
# Running on device :  cuda
# Epoch: 819, Batch: 100, Avg. Loss: 0.0005735319613013417
# Running on device :  cuda
# Epoch: 820, Batch: 100, Avg. Loss: 0.0006085284014698118
# Running on device :  cuda
# Epoch: 821, Batch: 100, Avg. Loss: 0.0005681990913581103
# Running on device :  cuda
# Epoch: 822, Batch: 100, Avg. Loss: 0.0005818637209013104
# Running on device :  cuda
# Epoch: 823, Batch: 100, Avg. Loss: 0.0006121227566618472
# Running on device :  cuda
# Epoch: 824, Batch: 100, Avg. Loss: 0.0005676657778676599
# Running on device :  cuda
# Epoch: 825, Batch: 100, Avg. Loss: 0.0006156182389240712
# Running on device :  cuda
# Epoch: 826, Batch: 100, Avg. Loss: 0.0006629750607535243
# Running on device :  cuda
# Epoch: 827, Batch: 100, Avg. Loss: 0.000587650771252811
# Running on device :  cuda
# Epoch: 828, Batch: 100, Avg. Loss: 0.0005711369351483882
# Running on device :  cuda
# Epoch: 829, Batch: 100, Avg. Loss: 0.0006168675655499101
# Running on device :  cuda
# Epoch: 830, Batch: 100, Avg. Loss: 0.0006111687393859029
# Running on device :  cuda
# Epoch: 831, Batch: 100, Avg. Loss: 0.0005773982780519873
# Running on device :  cuda
# Epoch: 832, Batch: 100, Avg. Loss: 0.0005837924142833799
# Running on device :  cuda
# Epoch: 833, Batch: 100, Avg. Loss: 0.000569493688410148
# Running on device :  cuda
# Epoch: 834, Batch: 100, Avg. Loss: 0.0005512645321432501
# Running on device :  cuda
# Epoch: 835, Batch: 100, Avg. Loss: 0.0005362421353347599
# Running on device :  cuda
# Epoch: 836, Batch: 100, Avg. Loss: 0.0005864750884938986
# Running on device :  cuda
# Epoch: 837, Batch: 100, Avg. Loss: 0.0005704073486849665
# Running on device :  cuda
# Epoch: 838, Batch: 100, Avg. Loss: 0.0005592362484894693
# Running on device :  cuda
# Epoch: 839, Batch: 100, Avg. Loss: 0.0005731999673880637
# Running on device :  cuda
# Epoch: 840, Batch: 100, Avg. Loss: 0.0005477672058623284
# Running on device :  cuda
# Epoch: 841, Batch: 100, Avg. Loss: 0.0005661919764243066
# Running on device :  cuda
# Epoch: 842, Batch: 100, Avg. Loss: 0.0005965410089120268
# Running on device :  cuda
# Epoch: 843, Batch: 100, Avg. Loss: 0.0005883237773086875
# Running on device :  cuda
# Epoch: 844, Batch: 100, Avg. Loss: 0.0005658066624309868
# Running on device :  cuda
# Epoch: 845, Batch: 100, Avg. Loss: 0.0005748317488469183
# Running on device :  cuda
# Epoch: 846, Batch: 100, Avg. Loss: 0.0005880304356105626
# Running on device :  cuda
# Epoch: 847, Batch: 100, Avg. Loss: 0.0005497923523653299
# Running on device :  cuda
# Epoch: 848, Batch: 100, Avg. Loss: 0.0006058473950251937
# Running on device :  cuda
# Epoch: 849, Batch: 100, Avg. Loss: 0.0005778148965910077
# Running on device :  cuda
# Epoch: 850, Batch: 100, Avg. Loss: 0.0005852467594668269
# Running on device :  cuda
# Epoch: 851, Batch: 100, Avg. Loss: 0.0005887162091676146
# Running on device :  cuda
# Epoch: 852, Batch: 100, Avg. Loss: 0.000618374576093629
# Running on device :  cuda
# Epoch: 853, Batch: 100, Avg. Loss: 0.0005588194993324578
# Running on device :  cuda
# Epoch: 854, Batch: 100, Avg. Loss: 0.0005830563073977828
# Running on device :  cuda
# Epoch: 855, Batch: 100, Avg. Loss: 0.00058673164434731
# Running on device :  cuda
# Epoch: 856, Batch: 100, Avg. Loss: 0.0005894045426975935
# Running on device :  cuda
# Epoch: 857, Batch: 100, Avg. Loss: 0.0005582406187895685
# Running on device :  cuda
# Epoch: 858, Batch: 100, Avg. Loss: 0.0005382031393237412
# Running on device :  cuda
# Epoch: 859, Batch: 100, Avg. Loss: 0.0005422315045725554
# Running on device :  cuda
# Epoch: 860, Batch: 100, Avg. Loss: 0.0005954895860049873
# Running on device :  cuda
# Epoch: 861, Batch: 100, Avg. Loss: 0.0005459055246319622
# Running on device :  cuda
# Epoch: 862, Batch: 100, Avg. Loss: 0.0005956903602927923
# Running on device :  cuda
# Epoch: 863, Batch: 100, Avg. Loss: 0.0005732430818025022
# Running on device :  cuda
# Epoch: 864, Batch: 100, Avg. Loss: 0.0005872347317636013
# Running on device :  cuda
# Epoch: 865, Batch: 100, Avg. Loss: 0.0005495555943343789
# Running on device :  cuda
# Epoch: 866, Batch: 100, Avg. Loss: 0.0005697015542536974
# Running on device :  cuda
# Epoch: 867, Batch: 100, Avg. Loss: 0.0005777656598947942
# Running on device :  cuda
# Epoch: 868, Batch: 100, Avg. Loss: 0.0006138426256366074
# Running on device :  cuda
# Epoch: 869, Batch: 100, Avg. Loss: 0.0005474642906337976
# Running on device :  cuda
# Epoch: 870, Batch: 100, Avg. Loss: 0.000552628458943218
# Running on device :  cuda
# Epoch: 871, Batch: 100, Avg. Loss: 0.000564510163385421
# Running on device :  cuda
# Epoch: 872, Batch: 100, Avg. Loss: 0.000575868425425142
# Running on device :  cuda
# Epoch: 873, Batch: 100, Avg. Loss: 0.0005336505903396756
# Running on device :  cuda
# Epoch: 874, Batch: 100, Avg. Loss: 0.0005859564007259906
# Running on device :  cuda
# Epoch: 875, Batch: 100, Avg. Loss: 0.0005768768799025566
# Running on device :  cuda
# Epoch: 876, Batch: 100, Avg. Loss: 0.0005452964222058653
# Running on device :  cuda
# Epoch: 877, Batch: 100, Avg. Loss: 0.0005494829418603331
# Running on device :  cuda
# Epoch: 878, Batch: 100, Avg. Loss: 0.0005722732588183134
# Running on device :  cuda
# Epoch: 879, Batch: 100, Avg. Loss: 0.0005929992084857076
# Running on device :  cuda
# Epoch: 880, Batch: 100, Avg. Loss: 0.0005834136628545821
# Running on device :  cuda
# Epoch: 881, Batch: 100, Avg. Loss: 0.0005454110198188573
# Running on device :  cuda
# Epoch: 882, Batch: 100, Avg. Loss: 0.0005614703407045454
# Running on device :  cuda
# Epoch: 883, Batch: 100, Avg. Loss: 0.0005618942237924784
# Running on device :  cuda
# Epoch: 884, Batch: 100, Avg. Loss: 0.0005541101589333266
# Running on device :  cuda
# Epoch: 885, Batch: 100, Avg. Loss: 0.0005514243165962398
# Running on device :  cuda
# Epoch: 886, Batch: 100, Avg. Loss: 0.0005804272922687232
# Running on device :  cuda
# Epoch: 887, Batch: 100, Avg. Loss: 0.0006059568384662271
# Running on device :  cuda
# Epoch: 888, Batch: 100, Avg. Loss: 0.0005755484809633344
# Running on device :  cuda
# Epoch: 889, Batch: 100, Avg. Loss: 0.0005617497921921313
# Running on device :  cuda
# Epoch: 890, Batch: 100, Avg. Loss: 0.0005953731273766607
# Running on device :  cuda
# Epoch: 891, Batch: 100, Avg. Loss: 0.0005433221587445587
# Running on device :  cuda
# Epoch: 892, Batch: 100, Avg. Loss: 0.0005596781577914953
# Running on device :  cuda
# Epoch: 893, Batch: 100, Avg. Loss: 0.0005784732792526484
# Running on device :  cuda
# Epoch: 894, Batch: 100, Avg. Loss: 0.0005361941589508205
# Running on device :  cuda
# Epoch: 895, Batch: 100, Avg. Loss: 0.0005353773999959231
# Running on device :  cuda
# Epoch: 896, Batch: 100, Avg. Loss: 0.0005606982216704637
# Running on device :  cuda
# Epoch: 897, Batch: 100, Avg. Loss: 0.0006322105373255908
# Running on device :  cuda
# Epoch: 898, Batch: 100, Avg. Loss: 0.0005423815911635756
# Running on device :  cuda
# Epoch: 899, Batch: 100, Avg. Loss: 0.0005583738253917545
# Running on device :  cuda
# Epoch: 900, Batch: 100, Avg. Loss: 0.0005473029790446163
# Running on device :  cuda
# Epoch: 901, Batch: 100, Avg. Loss: 0.0005526598184369504
# Running on device :  cuda
# Epoch: 902, Batch: 100, Avg. Loss: 0.0005477984210010618
# Running on device :  cuda
# Epoch: 903, Batch: 100, Avg. Loss: 0.0005837793147657066
# Running on device :  cuda
# Epoch: 904, Batch: 100, Avg. Loss: 0.0005957148766610772
# Running on device :  cuda
# Epoch: 905, Batch: 100, Avg. Loss: 0.0006204689941368998
# Running on device :  cuda
# Epoch: 906, Batch: 100, Avg. Loss: 0.0005162720256485045
# Running on device :  cuda
# Epoch: 907, Batch: 100, Avg. Loss: 0.0005594318646471948
# Running on device :  cuda
# Epoch: 908, Batch: 100, Avg. Loss: 0.0005649242650251835
# Running on device :  cuda
# Epoch: 909, Batch: 100, Avg. Loss: 0.00052789132646285
# Running on device :  cuda
# Epoch: 910, Batch: 100, Avg. Loss: 0.0005127069232985377
# Running on device :  cuda
# Epoch: 911, Batch: 100, Avg. Loss: 0.0005239646518602968
# Running on device :  cuda
# Epoch: 912, Batch: 100, Avg. Loss: 0.0005741451506037265
# Running on device :  cuda
# Epoch: 913, Batch: 100, Avg. Loss: 0.0006104583365377039
# Running on device :  cuda
# Epoch: 914, Batch: 100, Avg. Loss: 0.0005831766205374151
# Running on device :  cuda
# Epoch: 915, Batch: 100, Avg. Loss: 0.0005511025730520487
# Running on device :  cuda
# Epoch: 916, Batch: 100, Avg. Loss: 0.0005548011788632721
# Running on device :  cuda
# Epoch: 917, Batch: 100, Avg. Loss: 0.000583642611047253
# Running on device :  cuda
# Epoch: 918, Batch: 100, Avg. Loss: 0.0005824680037330836
# Running on device :  cuda
# Epoch: 919, Batch: 100, Avg. Loss: 0.0005358302649110556
# Running on device :  cuda
# Epoch: 920, Batch: 100, Avg. Loss: 0.0005609204103238881
# Running on device :  cuda
# Epoch: 921, Batch: 100, Avg. Loss: 0.000584610183024779
# Running on device :  cuda
# Epoch: 922, Batch: 100, Avg. Loss: 0.0005967967309989035
# Running on device :  cuda
# Epoch: 923, Batch: 100, Avg. Loss: 0.0005706305948551744
# Running on device :  cuda
# Epoch: 924, Batch: 100, Avg. Loss: 0.0005465364707633853
# Running on device :  cuda
# Epoch: 925, Batch: 100, Avg. Loss: 0.0005343217139597982
# Running on device :  cuda
# Epoch: 926, Batch: 100, Avg. Loss: 0.0005420488698873669
# Running on device :  cuda
# Epoch: 927, Batch: 100, Avg. Loss: 0.0005514332477468998
# Running on device :  cuda
# Epoch: 928, Batch: 100, Avg. Loss: 0.0005426450320519507
# Running on device :  cuda
# Epoch: 929, Batch: 100, Avg. Loss: 0.0005444893110543489
# Running on device :  cuda
# Epoch: 930, Batch: 100, Avg. Loss: 0.000575776543468237
# Running on device :  cuda
# Epoch: 931, Batch: 100, Avg. Loss: 0.000524387982673943
# Running on device :  cuda
# Epoch: 932, Batch: 100, Avg. Loss: 0.000587844955502078
# Running on device :  cuda
# Epoch: 933, Batch: 100, Avg. Loss: 0.0005107207670807839
# Running on device :  cuda
# Epoch: 934, Batch: 100, Avg. Loss: 0.0005239585973322392
# Running on device :  cuda
# Epoch: 935, Batch: 100, Avg. Loss: 0.0005304014580324293
# Running on device :  cuda
# Epoch: 936, Batch: 100, Avg. Loss: 0.0005387682125438005
# Running on device :  cuda
# Epoch: 937, Batch: 100, Avg. Loss: 0.0005274441144429147
# Running on device :  cuda
# Epoch: 938, Batch: 100, Avg. Loss: 0.0005414286071900278
# Running on device :  cuda
# Epoch: 939, Batch: 100, Avg. Loss: 0.0005177983730100096
# Running on device :  cuda
# Epoch: 940, Batch: 100, Avg. Loss: 0.0005353850652463734
# Running on device :  cuda
# Epoch: 941, Batch: 100, Avg. Loss: 0.0005343051583040505
# Running on device :  cuda
# Epoch: 942, Batch: 100, Avg. Loss: 0.0005483656127471477
# Running on device :  cuda
# Epoch: 943, Batch: 100, Avg. Loss: 0.0005273714486975223
# Running on device :  cuda
# Epoch: 944, Batch: 100, Avg. Loss: 0.0005423598478082567
# Running on device :  cuda
# Epoch: 945, Batch: 100, Avg. Loss: 0.0005701301982626319
# Running on device :  cuda
# Epoch: 946, Batch: 100, Avg. Loss: 0.0005382495096419007
# Running on device :  cuda
# Epoch: 947, Batch: 100, Avg. Loss: 0.0005231046970002353
# Running on device :  cuda
# Epoch: 948, Batch: 100, Avg. Loss: 0.0005017121646087617
# Running on device :  cuda
# Epoch: 949, Batch: 100, Avg. Loss: 0.00054120476054959
# Running on device :  cuda
# Epoch: 950, Batch: 100, Avg. Loss: 0.0005681376755237579
# Running on device :  cuda
# Epoch: 951, Batch: 100, Avg. Loss: 0.0005394268915988505
# Running on device :  cuda
# Epoch: 952, Batch: 100, Avg. Loss: 0.0005653792514931411
# Running on device :  cuda
# Epoch: 953, Batch: 100, Avg. Loss: 0.0005244836087804288
# Running on device :  cuda
# Epoch: 954, Batch: 100, Avg. Loss: 0.0005637741731479764
# Running on device :  cuda
# Epoch: 955, Batch: 100, Avg. Loss: 0.0005561933496501297
# Running on device :  cuda
# Epoch: 956, Batch: 100, Avg. Loss: 0.0005198807169217617
# Running on device :  cuda
# Epoch: 957, Batch: 100, Avg. Loss: 0.0005096333213150501
# Running on device :  cuda
# Epoch: 958, Batch: 100, Avg. Loss: 0.0005534591355826706
# Running on device :  cuda
# Epoch: 959, Batch: 100, Avg. Loss: 0.000513455398613587
# Running on device :  cuda
# Epoch: 960, Batch: 100, Avg. Loss: 0.0004929953617975115
# Running on device :  cuda
# Epoch: 961, Batch: 100, Avg. Loss: 0.0005018577924929559
# Running on device :  cuda
# Epoch: 962, Batch: 100, Avg. Loss: 0.0005630809802096337
# Running on device :  cuda
# Epoch: 963, Batch: 100, Avg. Loss: 0.00048123738076537846
# Running on device :  cuda
# Epoch: 964, Batch: 100, Avg. Loss: 0.00048010572465136646
# Running on device :  cuda
# Epoch: 965, Batch: 100, Avg. Loss: 0.0005362993543967605
# Running on device :  cuda
# Epoch: 966, Batch: 100, Avg. Loss: 0.0005580808187369258
# Running on device :  cuda
# Epoch: 967, Batch: 100, Avg. Loss: 0.0005252112587913871
# Running on device :  cuda
# Epoch: 968, Batch: 100, Avg. Loss: 0.0005284873601049184
# Running on device :  cuda
# Epoch: 969, Batch: 100, Avg. Loss: 0.0005334080380853265
# Running on device :  cuda
# Epoch: 970, Batch: 100, Avg. Loss: 0.0005781692578457296
# Running on device :  cuda
# Epoch: 971, Batch: 100, Avg. Loss: 0.0005047379394527525
# Running on device :  cuda
# Epoch: 972, Batch: 100, Avg. Loss: 0.0005340543526690453
# Running on device :  cuda
# Epoch: 973, Batch: 100, Avg. Loss: 0.00053915158030577
# Running on device :  cuda
# Epoch: 974, Batch: 100, Avg. Loss: 0.000496999487746507
# Running on device :  cuda
# Epoch: 975, Batch: 100, Avg. Loss: 0.000491464757360518
# Running on device :  cuda
# Epoch: 976, Batch: 100, Avg. Loss: 0.0005058348982129246
# Running on device :  cuda
# Epoch: 977, Batch: 100, Avg. Loss: 0.0005439296283293515
# Running on device :  cuda
# Epoch: 978, Batch: 100, Avg. Loss: 0.0005219322079792619
# Running on device :  cuda
# Epoch: 979, Batch: 100, Avg. Loss: 0.0005093758823350072
# Running on device :  cuda
# Epoch: 980, Batch: 100, Avg. Loss: 0.0005060495492070913
# Running on device :  cuda
# Epoch: 981, Batch: 100, Avg. Loss: 0.0005042117575649172
# Running on device :  cuda
# Epoch: 982, Batch: 100, Avg. Loss: 0.0005207300526089967
# Running on device :  cuda
# Epoch: 983, Batch: 100, Avg. Loss: 0.0005267179282382131
# Running on device :  cuda
# Epoch: 984, Batch: 100, Avg. Loss: 0.000522032086737454
# Running on device :  cuda
# Epoch: 985, Batch: 100, Avg. Loss: 0.0005168430898338556
# Running on device :  cuda
# Epoch: 986, Batch: 100, Avg. Loss: 0.0005637950119562447
# Running on device :  cuda
# Epoch: 987, Batch: 100, Avg. Loss: 0.0005448695225641131
# Running on device :  cuda
# Epoch: 988, Batch: 100, Avg. Loss: 0.0005480378097854555
# Running on device :  cuda
# Epoch: 989, Batch: 100, Avg. Loss: 0.0005443396160844713
# Running on device :  cuda
# Epoch: 990, Batch: 100, Avg. Loss: 0.0004935099505819381
# Running on device :  cuda
# Epoch: 991, Batch: 100, Avg. Loss: 0.0005499942107126117
# Running on device :  cuda
# Epoch: 992, Batch: 100, Avg. Loss: 0.0005256851562298834
# Running on device :  cuda
# Epoch: 993, Batch: 100, Avg. Loss: 0.0005137271084822714
# Running on device :  cuda
# Epoch: 994, Batch: 100, Avg. Loss: 0.0005012733093462885
# Running on device :  cuda
# Epoch: 995, Batch: 100, Avg. Loss: 0.0005053687223698943
# Running on device :  cuda
# Epoch: 996, Batch: 100, Avg. Loss: 0.0005498262855689973
# Running on device :  cuda
# Epoch: 997, Batch: 100, Avg. Loss: 0.0005146555674728006
# Running on device :  cuda
# Epoch: 998, Batch: 100, Avg. Loss: 0.0004879412387963384
# Running on device :  cuda
# Epoch: 999, Batch: 100, Avg. Loss: 0.0005758806464727968
# Running on device :  cuda
# Epoch: 1000, Batch: 100, Avg. Loss: 0.0005178017807193101
# Finished Training
#
# Training Accuracy (MSE):  0.356086180578

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())

print("\nAccuracy(MSE): ", accuracy_mse(test_outputs, gt_pts))
# Out:
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])
#
# Accuracy(MSE):  0.161973750726

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_3.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**:
# I chose SmoothL1Loss as the loss function. We need to compare the predicted values with the target values directly, therefore we can't use CrossEntropy (which is for classification problem).
#
# I first started with MSELoss, since we are prdicting points on a image, it makes sense to evaluate the results by calculating the Euclidean distance between the ground truth and predicted points. MSE is similar as Euclidean distance hence my choice. Besides, during training, MSE (or L2 loss) is more stable than L1 loss when error becomes small.
#
# Then I started to explore SmoothL1Loss. I read that Smooth L1-loss combines the advantages of L1-loss (steady gradients for large values of 𝑥, less sensitive to outliers) and L2-loss (less oscillations during updates when 𝑥 is small). And I found that I can achived smaller training loss by using SmoothL1Loss.
#
# For optimization I chose Adam since Adam gives better performance than SGD during training.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: I started the network architecture the same as the FasionMNIST solution notebook, and and chaneged the loss function to MSE. I got a relatively large loss after several epoches of training, and I knew this was highly likely to be under-fitting since the network was too small.
#
# I thought it might be a good ideas to get the network over-fitting first, then reducing latyers/filters to the right size. Hence I started adding more filters and more convolutional layers, and more dense fully connected layers, but soon I found it was too slow to train. Finnaly I refer to [this paper](https://arxiv.org/pdf/1710.00977.pdf) as suggested in the beginning of this notebook, and settles at 5 convolutional layers.
#
# After I got a satifactory training accuracy I found that my model did not perform well on test dataset, I believed this was a strong sign of overfitting hence I addin dropout layers after each conv/fc layers (except for the last layer)

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: batch_size: I read that samll batch_size may introduce some noises (since noises are generally averaged out by using larger batch_size), and large batch_size usually provies more accurate gradients during back-propogate. I know there is some techniques to calculate optimal bacth_size based on network size and GPU memory but in this project I just manually test them and I found batch_size of 32 gave a nice result, while batch_size of 64 uasually causes a memory issue.
#
# For number of epochs, I found the loss did not decrease anymore around 250 cycles hence I just set it to  be 300. I think usually the higher the better, but it also depends on the errors since sometimes more taining doesn't really help reducing the loss.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 1

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[ 0.0911164  -0.00982611  0.11517657  0.03503106  0.10340211]
#  [ 0.04355418 -0.00107649  0.01428283 -0.0510931  -0.02534723]
#  [-0.04014902  0.01404374  0.04590347  0.06112901  0.05945934]
#  [-0.0304144  -0.00435304 -0.0576334   0.00098422  0.0804739 ]
#  [-0.06071811 -0.08420143 -0.05442635 -0.02109304 -0.0003804 ]]
# (5, 5)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset
import cv2
number = 100
sample = test_dataset[number]
image = sample['image']

# un-transform the image data
image = image.data   # get the image from it's wrapper
image = image.cpu().numpy()   # convert to numpy array from a Tensor
image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
plt.figure(figsize=(12,6))
ax = plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(image), cmap = 'gray')
ax = plt.subplot(1, 2, 2)
filtered_image = cv2.filter2D(image, -1, w[filter_index][0])
plt.imshow(filtered_image, cmap = 'gray')

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: This 5x5 filter mainly detects lines along vertical direction (looks like not just vertical, but within a range of angles) hence it's a line detector.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
