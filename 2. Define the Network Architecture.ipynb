# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

net = Net().to(device)
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#   (dropout): Dropout(p=0.5)
#   (fc1): Linear(in_features=18432, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=2048, bias=True)
#   (fc3): Linear(in_features=2048, out_features=136, bias=True)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])


# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 32

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints'].to(device)

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor).to(device)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images.cpu(), output_pts.cpu(), key_pts.cpu()

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# net_sample
#
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='r')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        image = image.cpu().numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.cpu().numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

# criterion = nn.MSELoss()

criterion = nn.SmoothL1Loss()

# optimizer = optim.SGD(net.parameters(), lr=0.0001, momentum=0.9)

optimizer = optim.Adam(net.parameters(), lr = 1e-4, betas=(0.9, 0.999), eps=1e-08)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
# Calculate accuracy so that we can compare different models/lossFunctions
def accuracy_mse(test_outputs, gt_pts):
    # move to cpu and convert back to np array
    predicted_key_pts = test_outputs.data.cpu().numpy()
    gt_key_points = gt_pts.data.cpu().numpy()
    
    predicted_key_pts = predicted_key_pts
    gt_key_points = gt_key_points
    
    se_sum = 0.0
    for idx in range(predicted_key_pts.shape[0]):
        res_x = predicted_key_pts[idx, :, 0] - gt_key_points[idx, :, 0]
        res_y = predicted_key_pts[idx, :, 1] - gt_key_points[idx, :, 1]
        se = np.sum(res_x ** 2 + res_y ** 2)
        se_sum += se
        # print(mse)
        
    mse = se_sum / predicted_key_pts.shape[0]
    return mse

# %%
def train_net(n_epochs):

    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        print("Running on device : ", device)
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            

            # forward pass to get outputs
            output_pts = net(images.to(device))
            

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts.to(device))

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            # to convert loss into a scalar and add it to the running_loss, use .item()
            running_loss += loss.item()
            if batch_i % 100 == 99:    # print every 50 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(epoch + 1, batch_i+1, running_loss/1000))
                running_loss = 0.0

    print('Finished Training')
    
    # Get accuracy by running another non-updating epoch
    mse = 0.0
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            
            # forward pass to get outputs
            output_pts = net(images.to(device))
            
            # reshape to batch_size x 68 x 2 pts
            output_pts = output_pts.view(output_pts.size()[0], 68, -1)
            key_pts = key_pts.view(output_pts.size()[0], 68, -1)
            
            mse += accuracy_mse(output_pts, key_pts)

    print('\nTraining Accuracy (MSE): ', mse/(batch_i+1))

# %%
# train your network
n_epochs = 1000 # start small, and increase when you've decided on your model structure and hyperparams

train_net(n_epochs)
# Out:
# Running on device :  cuda
# Epoch: 1, Batch: 100, Avg. Loss: 0.008062516659498215
# Running on device :  cuda
# Epoch: 2, Batch: 100, Avg. Loss: 0.007891210839152335
# Running on device :  cuda
# Epoch: 3, Batch: 100, Avg. Loss: 0.007698321424424648
# Running on device :  cuda
# Epoch: 4, Batch: 100, Avg. Loss: 0.007338968701660633
# Running on device :  cuda
# Epoch: 5, Batch: 100, Avg. Loss: 0.007355680242180824
# Running on device :  cuda
# Epoch: 6, Batch: 100, Avg. Loss: 0.006815432127565146
# Running on device :  cuda
# Epoch: 7, Batch: 100, Avg. Loss: 0.00693207836151123
# Running on device :  cuda
# Epoch: 8, Batch: 100, Avg. Loss: 0.006536700747907162
# Running on device :  cuda
# Epoch: 9, Batch: 100, Avg. Loss: 0.006566063724458218
# Running on device :  cuda
# Epoch: 10, Batch: 100, Avg. Loss: 0.006202219624072313
# Running on device :  cuda
# Epoch: 11, Batch: 100, Avg. Loss: 0.006197228956967592
# Running on device :  cuda
# Epoch: 12, Batch: 100, Avg. Loss: 0.006119488872587681
# Running on device :  cuda
# Epoch: 13, Batch: 100, Avg. Loss: 0.006100242551416159
# Running on device :  cuda
# Epoch: 14, Batch: 100, Avg. Loss: 0.005943054746836424
# Running on device :  cuda
# Epoch: 15, Batch: 100, Avg. Loss: 0.0057280207574367525
# Running on device :  cuda
# Epoch: 16, Batch: 100, Avg. Loss: 0.005826411213725805
# Running on device :  cuda
# Epoch: 17, Batch: 100, Avg. Loss: 0.005768463797867298
# Running on device :  cuda
# Epoch: 18, Batch: 100, Avg. Loss: 0.00543576705083251
# Running on device :  cuda
# Epoch: 19, Batch: 100, Avg. Loss: 0.005491785693913698
# Running on device :  cuda
# Epoch: 20, Batch: 100, Avg. Loss: 0.005338949088007212
# Running on device :  cuda
# Epoch: 21, Batch: 100, Avg. Loss: 0.005406058941036463
# Running on device :  cuda
# Epoch: 22, Batch: 100, Avg. Loss: 0.005353085029870272
# Running on device :  cuda
# Epoch: 23, Batch: 100, Avg. Loss: 0.0051024041585624215
# Running on device :  cuda
# Epoch: 24, Batch: 100, Avg. Loss: 0.005099116824567318
# Running on device :  cuda
# Epoch: 25, Batch: 100, Avg. Loss: 0.004884441820904612
# Running on device :  cuda
# Epoch: 26, Batch: 100, Avg. Loss: 0.005093213325366378
# Running on device :  cuda
# Epoch: 27, Batch: 100, Avg. Loss: 0.004938147764652967
# Running on device :  cuda
# Epoch: 28, Batch: 100, Avg. Loss: 0.004660818945616483
# Running on device :  cuda
# Epoch: 29, Batch: 100, Avg. Loss: 0.00448875736258924
# Running on device :  cuda
# Epoch: 30, Batch: 100, Avg. Loss: 0.004515968350693583
# Running on device :  cuda
# Epoch: 31, Batch: 100, Avg. Loss: 0.004203655401244759
# Running on device :  cuda
# Epoch: 32, Batch: 100, Avg. Loss: 0.004316529711708426
# Running on device :  cuda
# Epoch: 33, Batch: 100, Avg. Loss: 0.004062624882906676
# Running on device :  cuda
# Epoch: 34, Batch: 100, Avg. Loss: 0.0041031812150031325
# Running on device :  cuda
# Epoch: 35, Batch: 100, Avg. Loss: 0.0038544787261635067
# Running on device :  cuda
# Epoch: 36, Batch: 100, Avg. Loss: 0.003897594965994358
# Running on device :  cuda
# Epoch: 37, Batch: 100, Avg. Loss: 0.0036848942078649997
# Running on device :  cuda
# Epoch: 38, Batch: 100, Avg. Loss: 0.003739953296259046
# Running on device :  cuda
# Epoch: 39, Batch: 100, Avg. Loss: 0.0036314670611172916
# Running on device :  cuda
# Epoch: 40, Batch: 100, Avg. Loss: 0.003875326182693243
# Running on device :  cuda
# Epoch: 41, Batch: 100, Avg. Loss: 0.003510056244209409
# Running on device :  cuda
# Epoch: 42, Batch: 100, Avg. Loss: 0.0035681628305464985
# Running on device :  cuda
# Epoch: 43, Batch: 100, Avg. Loss: 0.003526837242767215
# Running on device :  cuda
# Epoch: 44, Batch: 100, Avg. Loss: 0.003408580880612135
# Running on device :  cuda
# Epoch: 45, Batch: 100, Avg. Loss: 0.0033377074003219606
# Running on device :  cuda
# Epoch: 46, Batch: 100, Avg. Loss: 0.0033893207116052508
# Running on device :  cuda
# Epoch: 47, Batch: 100, Avg. Loss: 0.0031895016711205246
# Running on device :  cuda
# Epoch: 48, Batch: 100, Avg. Loss: 0.003058808661997318
# Running on device :  cuda
# Epoch: 49, Batch: 100, Avg. Loss: 0.003128856848925352
# Running on device :  cuda
# Epoch: 50, Batch: 100, Avg. Loss: 0.0030687415478751062
# Running on device :  cuda
# Epoch: 51, Batch: 100, Avg. Loss: 0.0028781050657853482
# Running on device :  cuda
# Epoch: 52, Batch: 100, Avg. Loss: 0.002962829437106848
# Running on device :  cuda
# Epoch: 53, Batch: 100, Avg. Loss: 0.0030629313373938204
# Running on device :  cuda
# Epoch: 54, Batch: 100, Avg. Loss: 0.0029502469580620526
# Running on device :  cuda
# Epoch: 55, Batch: 100, Avg. Loss: 0.003060141853056848
# Running on device :  cuda
# Epoch: 56, Batch: 100, Avg. Loss: 0.0028952101608738304
# Running on device :  cuda
# Epoch: 57, Batch: 100, Avg. Loss: 0.002822040032595396
# Running on device :  cuda
# Epoch: 58, Batch: 100, Avg. Loss: 0.0028414152320474385
# Running on device :  cuda
# Epoch: 59, Batch: 100, Avg. Loss: 0.0028466085651889443
# Running on device :  cuda
# Epoch: 60, Batch: 100, Avg. Loss: 0.0028187128696590662
# Running on device :  cuda
# Epoch: 61, Batch: 100, Avg. Loss: 0.0026003915164619683
# Running on device :  cuda
# Epoch: 62, Batch: 100, Avg. Loss: 0.00276749455742538
# Running on device :  cuda
# Epoch: 63, Batch: 100, Avg. Loss: 0.002640996306203306
# Running on device :  cuda
# Epoch: 64, Batch: 100, Avg. Loss: 0.0025194685105234386
# Running on device :  cuda
# Epoch: 65, Batch: 100, Avg. Loss: 0.002692402170971036
# Running on device :  cuda
# Epoch: 66, Batch: 100, Avg. Loss: 0.0025450571654364465
# Running on device :  cuda
# Epoch: 67, Batch: 100, Avg. Loss: 0.0024953570468351245
# Running on device :  cuda
# Epoch: 68, Batch: 100, Avg. Loss: 0.002500978464260697
# Running on device :  cuda
# Epoch: 69, Batch: 100, Avg. Loss: 0.0026370467422530057
# Running on device :  cuda
# Epoch: 70, Batch: 100, Avg. Loss: 0.0023842421881854533
# Running on device :  cuda
# Epoch: 71, Batch: 100, Avg. Loss: 0.002408882101997733
# Running on device :  cuda
# Epoch: 72, Batch: 100, Avg. Loss: 0.0025404261173680425
# Running on device :  cuda
# Epoch: 73, Batch: 100, Avg. Loss: 0.002296813608147204
# Running on device :  cuda
# Epoch: 74, Batch: 100, Avg. Loss: 0.002452489306218922
# Running on device :  cuda
# Epoch: 75, Batch: 100, Avg. Loss: 0.0025209714192897083
# Running on device :  cuda
# Epoch: 76, Batch: 100, Avg. Loss: 0.0023104240326210857
# Running on device :  cuda
# Epoch: 77, Batch: 100, Avg. Loss: 0.0023736266484484076
# Running on device :  cuda
# Epoch: 78, Batch: 100, Avg. Loss: 0.0024935163846239445
# Running on device :  cuda
# Epoch: 79, Batch: 100, Avg. Loss: 0.0021440229220315815
# Running on device :  cuda
# Epoch: 80, Batch: 100, Avg. Loss: 0.002397726560011506
# Running on device :  cuda
# Epoch: 81, Batch: 100, Avg. Loss: 0.0023277610372751953
# Running on device :  cuda
# Epoch: 82, Batch: 100, Avg. Loss: 0.0023653794955462216
# Running on device :  cuda
# Epoch: 83, Batch: 100, Avg. Loss: 0.0020952661242336036
# Running on device :  cuda
# Epoch: 84, Batch: 100, Avg. Loss: 0.002226826963946223
# Running on device :  cuda
# Epoch: 85, Batch: 100, Avg. Loss: 0.002098055615089834
# Running on device :  cuda
# Epoch: 86, Batch: 100, Avg. Loss: 0.0022424475122243166
# Running on device :  cuda
# Epoch: 87, Batch: 100, Avg. Loss: 0.0022083980180323125
# Running on device :  cuda
# Epoch: 88, Batch: 100, Avg. Loss: 0.002258694637566805
# Running on device :  cuda
# Epoch: 89, Batch: 100, Avg. Loss: 0.0021075804885476827
# Running on device :  cuda
# Epoch: 90, Batch: 100, Avg. Loss: 0.0023545563109219074
# Running on device :  cuda
# Epoch: 91, Batch: 100, Avg. Loss: 0.002076837543398142
# Running on device :  cuda
# Epoch: 92, Batch: 100, Avg. Loss: 0.0022588700270280244
# Running on device :  cuda
# Epoch: 93, Batch: 100, Avg. Loss: 0.0020868116188794373
# Running on device :  cuda
# Epoch: 94, Batch: 100, Avg. Loss: 0.002057819158770144
# Running on device :  cuda
# Epoch: 95, Batch: 100, Avg. Loss: 0.0018490895777940751
# Running on device :  cuda
# Epoch: 96, Batch: 100, Avg. Loss: 0.002059179629199207
# Running on device :  cuda
# Epoch: 97, Batch: 100, Avg. Loss: 0.001969380095601082
# Running on device :  cuda
# Epoch: 98, Batch: 100, Avg. Loss: 0.0019111604252830148
# Running on device :  cuda
# Epoch: 99, Batch: 100, Avg. Loss: 0.0018865257259458304
# Running on device :  cuda
# Epoch: 100, Batch: 100, Avg. Loss: 0.0019267370030283928
# Running on device :  cuda
# Epoch: 101, Batch: 100, Avg. Loss: 0.00208981603756547
# Running on device :  cuda
# Epoch: 102, Batch: 100, Avg. Loss: 0.0020298638874664903
# Running on device :  cuda
# Epoch: 103, Batch: 100, Avg. Loss: 0.0019055923391133546
# Running on device :  cuda
# Epoch: 104, Batch: 100, Avg. Loss: 0.0018400442646816374
# Running on device :  cuda
# Epoch: 105, Batch: 100, Avg. Loss: 0.0019776845145970585
# Running on device :  cuda
# Epoch: 106, Batch: 100, Avg. Loss: 0.002022971567697823
# Running on device :  cuda
# Epoch: 107, Batch: 100, Avg. Loss: 0.0019717125771567226
# Running on device :  cuda
# Epoch: 108, Batch: 100, Avg. Loss: 0.001773230016231537
# Running on device :  cuda
# Epoch: 109, Batch: 100, Avg. Loss: 0.0019217674331739544
# Running on device :  cuda
# Epoch: 110, Batch: 100, Avg. Loss: 0.0019922370556741953
# Running on device :  cuda
# Epoch: 111, Batch: 100, Avg. Loss: 0.0017757312636822462
# Running on device :  cuda
# Epoch: 112, Batch: 100, Avg. Loss: 0.0019038684470579028
# Running on device :  cuda
# Epoch: 113, Batch: 100, Avg. Loss: 0.0017034910451620817
# Running on device :  cuda
# Epoch: 114, Batch: 100, Avg. Loss: 0.0018109309757128357
# Running on device :  cuda
# Epoch: 115, Batch: 100, Avg. Loss: 0.0017561297565698625
# Running on device :  cuda
# Epoch: 116, Batch: 100, Avg. Loss: 0.0017376392455771565
# Running on device :  cuda
# Epoch: 117, Batch: 100, Avg. Loss: 0.001720594372600317
# Running on device :  cuda
# Epoch: 118, Batch: 100, Avg. Loss: 0.0018393988683819771
# Running on device :  cuda
# Epoch: 119, Batch: 100, Avg. Loss: 0.0017648317497223616
# Running on device :  cuda
# Epoch: 120, Batch: 100, Avg. Loss: 0.0018713236739858986
# Running on device :  cuda
# Epoch: 121, Batch: 100, Avg. Loss: 0.0018427198920398951
# Running on device :  cuda
# Epoch: 122, Batch: 100, Avg. Loss: 0.0018717009844258427
# Running on device :  cuda
# Epoch: 123, Batch: 100, Avg. Loss: 0.001594757835380733
# Running on device :  cuda
# Epoch: 124, Batch: 100, Avg. Loss: 0.0017652970617637038
# Running on device :  cuda
# Epoch: 125, Batch: 100, Avg. Loss: 0.0017150488356128335
# Running on device :  cuda
# Epoch: 126, Batch: 100, Avg. Loss: 0.0016736316252499819
# Running on device :  cuda
# Epoch: 127, Batch: 100, Avg. Loss: 0.0016363901989534498
# Running on device :  cuda
# Epoch: 128, Batch: 100, Avg. Loss: 0.001597699928097427
# Running on device :  cuda
# Epoch: 129, Batch: 100, Avg. Loss: 0.00163334574829787
# Running on device :  cuda
# Epoch: 130, Batch: 100, Avg. Loss: 0.0017402775529772043
# Running on device :  cuda
# Epoch: 131, Batch: 100, Avg. Loss: 0.0018059790087863804
# Running on device :  cuda
# Epoch: 132, Batch: 100, Avg. Loss: 0.001745341656729579
# Running on device :  cuda
# Epoch: 133, Batch: 100, Avg. Loss: 0.0017141694147139788
# Running on device :  cuda
# Epoch: 134, Batch: 100, Avg. Loss: 0.0016908374847844243
# Running on device :  cuda
# Epoch: 135, Batch: 100, Avg. Loss: 0.0016966862920671701
# Running on device :  cuda
# Epoch: 136, Batch: 100, Avg. Loss: 0.0016884045181795955
# Running on device :  cuda
# Epoch: 137, Batch: 100, Avg. Loss: 0.0016795306904241443
# Running on device :  cuda
# Epoch: 138, Batch: 100, Avg. Loss: 0.0016428679218515754
# Running on device :  cuda
# Epoch: 139, Batch: 100, Avg. Loss: 0.0015839229179546237
# Running on device :  cuda
# Epoch: 140, Batch: 100, Avg. Loss: 0.0016283256057649852
# Running on device :  cuda
# Epoch: 141, Batch: 100, Avg. Loss: 0.0016922333035618068
# Running on device :  cuda
# Epoch: 142, Batch: 100, Avg. Loss: 0.0017463364964351057
# Running on device :  cuda
# Epoch: 143, Batch: 100, Avg. Loss: 0.001666613000445068
# Running on device :  cuda
# Epoch: 144, Batch: 100, Avg. Loss: 0.0015021658074110746
# Running on device :  cuda
# Epoch: 145, Batch: 100, Avg. Loss: 0.001743370404932648
# Running on device :  cuda
# Epoch: 146, Batch: 100, Avg. Loss: 0.001704787996597588
# Running on device :  cuda
# Epoch: 147, Batch: 100, Avg. Loss: 0.0015666233054362237
# Running on device :  cuda
# Epoch: 148, Batch: 100, Avg. Loss: 0.0015725023122504353
# Running on device :  cuda
# Epoch: 149, Batch: 100, Avg. Loss: 0.0017353204302489758
# Running on device :  cuda
# Epoch: 150, Batch: 100, Avg. Loss: 0.0015371000226587057
# Running on device :  cuda
# Epoch: 151, Batch: 100, Avg. Loss: 0.0015163921299390494
# Running on device :  cuda
# Epoch: 152, Batch: 100, Avg. Loss: 0.0014894189955666662
# Running on device :  cuda
# Epoch: 153, Batch: 100, Avg. Loss: 0.0015667389342561365
# Running on device :  cuda
# Epoch: 154, Batch: 100, Avg. Loss: 0.0016593044260516763
# Running on device :  cuda
# Epoch: 155, Batch: 100, Avg. Loss: 0.0015401486158370971
# Running on device :  cuda
# Epoch: 156, Batch: 100, Avg. Loss: 0.001626715773716569
# Running on device :  cuda
# Epoch: 157, Batch: 100, Avg. Loss: 0.0014743911093100905
# Running on device :  cuda
# Epoch: 158, Batch: 100, Avg. Loss: 0.001653490456752479
# Running on device :  cuda
# Epoch: 159, Batch: 100, Avg. Loss: 0.001477741855196655
# Running on device :  cuda
# Epoch: 160, Batch: 100, Avg. Loss: 0.001487245824187994
# Running on device :  cuda
# Epoch: 161, Batch: 100, Avg. Loss: 0.0016061636032536626
# Running on device :  cuda
# Epoch: 162, Batch: 100, Avg. Loss: 0.001365693936124444
# Running on device :  cuda
# Epoch: 163, Batch: 100, Avg. Loss: 0.0016367761082947253
# Running on device :  cuda
# Epoch: 164, Batch: 100, Avg. Loss: 0.0015379581367596985
# Running on device :  cuda
# Epoch: 165, Batch: 100, Avg. Loss: 0.001581404502503574
# Running on device :  cuda
# Epoch: 166, Batch: 100, Avg. Loss: 0.0014514048276469112
# Running on device :  cuda
# Epoch: 167, Batch: 100, Avg. Loss: 0.0014080825867131353
# Running on device :  cuda
# Epoch: 168, Batch: 100, Avg. Loss: 0.0015013904068619014
# Running on device :  cuda
# Epoch: 169, Batch: 100, Avg. Loss: 0.0014283141549676656
# Running on device :  cuda
# Epoch: 170, Batch: 100, Avg. Loss: 0.0013611858822405339
# Running on device :  cuda
# Epoch: 171, Batch: 100, Avg. Loss: 0.0014693011296913027
# Running on device :  cuda
# Epoch: 172, Batch: 100, Avg. Loss: 0.0015086339972913265
# Running on device :  cuda
# Epoch: 173, Batch: 100, Avg. Loss: 0.0015819015186280011
# Running on device :  cuda
# Epoch: 174, Batch: 100, Avg. Loss: 0.0014444769620895386
# Running on device :  cuda
# Epoch: 175, Batch: 100, Avg. Loss: 0.0015206313906237483
# Running on device :  cuda
# Epoch: 176, Batch: 100, Avg. Loss: 0.0013241473231464624
# Running on device :  cuda
# Epoch: 177, Batch: 100, Avg. Loss: 0.001326081683859229
# Running on device :  cuda
# Epoch: 178, Batch: 100, Avg. Loss: 0.001325372613966465
# Running on device :  cuda
# Epoch: 179, Batch: 100, Avg. Loss: 0.0013260854966938495
# Running on device :  cuda
# Epoch: 180, Batch: 100, Avg. Loss: 0.0014789719507098198
# Running on device :  cuda
# Epoch: 181, Batch: 100, Avg. Loss: 0.001391270462423563
# Running on device :  cuda
# Epoch: 182, Batch: 100, Avg. Loss: 0.001378719954751432
# Running on device :  cuda
# Epoch: 183, Batch: 100, Avg. Loss: 0.001510615217499435
# Running on device :  cuda
# Epoch: 184, Batch: 100, Avg. Loss: 0.0013614727891981602
# Running on device :  cuda
# Epoch: 185, Batch: 100, Avg. Loss: 0.0013167598759755493
# Running on device :  cuda
# Epoch: 186, Batch: 100, Avg. Loss: 0.0013973250207491219
# Running on device :  cuda
# Epoch: 187, Batch: 100, Avg. Loss: 0.0013738232934847475
# Running on device :  cuda
# Epoch: 188, Batch: 100, Avg. Loss: 0.0013398539675399661
# Running on device :  cuda
# Epoch: 189, Batch: 100, Avg. Loss: 0.0013499735640361906
# Running on device :  cuda
# Epoch: 190, Batch: 100, Avg. Loss: 0.0014346344396471977
# Running on device :  cuda
# Epoch: 191, Batch: 100, Avg. Loss: 0.0014332622750662268
# Running on device :  cuda
# Epoch: 192, Batch: 100, Avg. Loss: 0.0014109157607890665
# Running on device :  cuda
# Epoch: 193, Batch: 100, Avg. Loss: 0.0013504912042990327
# Running on device :  cuda
# Epoch: 194, Batch: 100, Avg. Loss: 0.0014129028152674436
# Running on device :  cuda
# Epoch: 195, Batch: 100, Avg. Loss: 0.0013548679533414542
# Running on device :  cuda
# Epoch: 196, Batch: 100, Avg. Loss: 0.0012855791747570038
# Running on device :  cuda
# Epoch: 197, Batch: 100, Avg. Loss: 0.0013358528772369027
# Running on device :  cuda
# Epoch: 198, Batch: 100, Avg. Loss: 0.0013916933685541152
# Running on device :  cuda
# Epoch: 199, Batch: 100, Avg. Loss: 0.0013473547846078872
# Running on device :  cuda
# Epoch: 200, Batch: 100, Avg. Loss: 0.0013557496834546328
# Running on device :  cuda
# Epoch: 201, Batch: 100, Avg. Loss: 0.0013985671238042415
# Running on device :  cuda
# Epoch: 202, Batch: 100, Avg. Loss: 0.0012812004638835788
# Running on device :  cuda
# Epoch: 203, Batch: 100, Avg. Loss: 0.001266610831953585
# Running on device :  cuda
# Epoch: 204, Batch: 100, Avg. Loss: 0.0013752826587297023
# Running on device :  cuda
# Epoch: 205, Batch: 100, Avg. Loss: 0.001391105846967548
# Running on device :  cuda
# Epoch: 206, Batch: 100, Avg. Loss: 0.001351481547113508
# Running on device :  cuda
# Epoch: 207, Batch: 100, Avg. Loss: 0.001258960273116827
# Running on device :  cuda
# Epoch: 208, Batch: 100, Avg. Loss: 0.0012316004959866404
# Running on device :  cuda
# Epoch: 209, Batch: 100, Avg. Loss: 0.0012925296053290366
# Running on device :  cuda
# Epoch: 210, Batch: 100, Avg. Loss: 0.0012833881289698184
# Running on device :  cuda
# Epoch: 211, Batch: 100, Avg. Loss: 0.0011667676954530179
# Running on device :  cuda
# Epoch: 212, Batch: 100, Avg. Loss: 0.001294701339211315
# Running on device :  cuda
# Epoch: 213, Batch: 100, Avg. Loss: 0.0013430243637412786
# Running on device :  cuda
# Epoch: 214, Batch: 100, Avg. Loss: 0.0014327666657045484
# Running on device :  cuda
# Epoch: 215, Batch: 100, Avg. Loss: 0.0014051394634880126
# Running on device :  cuda
# Epoch: 216, Batch: 100, Avg. Loss: 0.0012268162248656154
# Running on device :  cuda
# Epoch: 217, Batch: 100, Avg. Loss: 0.0012673220769502222
# Running on device :  cuda
# Epoch: 218, Batch: 100, Avg. Loss: 0.001230161265935749
# Running on device :  cuda
# Epoch: 219, Batch: 100, Avg. Loss: 0.0012476542508229613
# Running on device :  cuda
# Epoch: 220, Batch: 100, Avg. Loss: 0.0012060122461989523
# Running on device :  cuda
# Epoch: 221, Batch: 100, Avg. Loss: 0.0013313643815927208
# Running on device :  cuda
# Epoch: 222, Batch: 100, Avg. Loss: 0.0013300435114651918
# Running on device :  cuda
# Epoch: 223, Batch: 100, Avg. Loss: 0.0012607064652256667
# Running on device :  cuda
# Epoch: 224, Batch: 100, Avg. Loss: 0.0012788330265320837
# Running on device :  cuda
# Epoch: 225, Batch: 100, Avg. Loss: 0.0012312507908791303
# Running on device :  cuda
# Epoch: 226, Batch: 100, Avg. Loss: 0.001240338807925582
# Running on device :  cuda
# Epoch: 227, Batch: 100, Avg. Loss: 0.0012442740644328296
# Running on device :  cuda
# Epoch: 228, Batch: 100, Avg. Loss: 0.0013795229718089105
# Running on device :  cuda
# Epoch: 229, Batch: 100, Avg. Loss: 0.0011647123573347927
# Running on device :  cuda
# Epoch: 230, Batch: 100, Avg. Loss: 0.0012658141278661787
# Running on device :  cuda
# Epoch: 231, Batch: 100, Avg. Loss: 0.0011650134255178273
# Running on device :  cuda
# Epoch: 232, Batch: 100, Avg. Loss: 0.0012388144615106285
# Running on device :  cuda
# Epoch: 233, Batch: 100, Avg. Loss: 0.0012870198474265635
# Running on device :  cuda
# Epoch: 234, Batch: 100, Avg. Loss: 0.0013011379381641746
# Running on device :  cuda
# Epoch: 235, Batch: 100, Avg. Loss: 0.0014203419131226837
# Running on device :  cuda
# Epoch: 236, Batch: 100, Avg. Loss: 0.001228137580677867
# Running on device :  cuda
# Epoch: 237, Batch: 100, Avg. Loss: 0.001216700683347881
# Running on device :  cuda
# Epoch: 238, Batch: 100, Avg. Loss: 0.0011579730892553926
# Running on device :  cuda
# Epoch: 239, Batch: 100, Avg. Loss: 0.001215286030434072
# Running on device :  cuda
# Epoch: 240, Batch: 100, Avg. Loss: 0.0012336036460474133
# Running on device :  cuda
# Epoch: 241, Batch: 100, Avg. Loss: 0.0012485484811477364
# Running on device :  cuda
# Epoch: 242, Batch: 100, Avg. Loss: 0.0012053716015070677
# Running on device :  cuda
# Epoch: 243, Batch: 100, Avg. Loss: 0.0011813024929724634
# Running on device :  cuda
# Epoch: 244, Batch: 100, Avg. Loss: 0.00131272746110335
# Running on device :  cuda
# Epoch: 245, Batch: 100, Avg. Loss: 0.0011670098938047885
# Running on device :  cuda
# Epoch: 246, Batch: 100, Avg. Loss: 0.0012621014327742158
# Running on device :  cuda
# Epoch: 247, Batch: 100, Avg. Loss: 0.0011458844789303839
# Running on device :  cuda
# Epoch: 248, Batch: 100, Avg. Loss: 0.0011686737784184515
# Running on device :  cuda
# Epoch: 249, Batch: 100, Avg. Loss: 0.0011665158751420677
# Running on device :  cuda
# Epoch: 250, Batch: 100, Avg. Loss: 0.0012489210027270018
# Running on device :  cuda
# Epoch: 251, Batch: 100, Avg. Loss: 0.0012216768902726472
# Running on device :  cuda
# Epoch: 252, Batch: 100, Avg. Loss: 0.0012307853596284985
# Running on device :  cuda
# Epoch: 253, Batch: 100, Avg. Loss: 0.001330896658822894
# Running on device :  cuda
# Epoch: 254, Batch: 100, Avg. Loss: 0.0012041891957633197
# Running on device :  cuda
# Epoch: 255, Batch: 100, Avg. Loss: 0.0012258491911925375
# Running on device :  cuda
# Epoch: 256, Batch: 100, Avg. Loss: 0.0012450449937023223
# Running on device :  cuda
# Epoch: 257, Batch: 100, Avg. Loss: 0.0011323475213721394
# Running on device :  cuda
# Epoch: 258, Batch: 100, Avg. Loss: 0.0011628087693825364
# Running on device :  cuda
# Epoch: 259, Batch: 100, Avg. Loss: 0.0011069084368646146
# Running on device :  cuda
# Epoch: 260, Batch: 100, Avg. Loss: 0.001117129829712212
# Running on device :  cuda
# Epoch: 261, Batch: 100, Avg. Loss: 0.0012179754385724664
# Running on device :  cuda
# Epoch: 262, Batch: 100, Avg. Loss: 0.0011090591601096093
# Running on device :  cuda
# Epoch: 263, Batch: 100, Avg. Loss: 0.0012169065084308387
# Running on device :  cuda
# Epoch: 264, Batch: 100, Avg. Loss: 0.0012032509869895876
# Running on device :  cuda
# Epoch: 265, Batch: 100, Avg. Loss: 0.0011824598661623895
# Running on device :  cuda
# Epoch: 266, Batch: 100, Avg. Loss: 0.0013052252940833568
# Running on device :  cuda
# Epoch: 267, Batch: 100, Avg. Loss: 0.0011107392790727316
# Running on device :  cuda
# Epoch: 268, Batch: 100, Avg. Loss: 0.001132100606802851
# Running on device :  cuda
# Epoch: 269, Batch: 100, Avg. Loss: 0.0012383177070878445
# Running on device :  cuda
# Epoch: 270, Batch: 100, Avg. Loss: 0.0011646384517662227
# Running on device :  cuda
# Epoch: 271, Batch: 100, Avg. Loss: 0.0011464670784771442
# Running on device :  cuda
# Epoch: 272, Batch: 100, Avg. Loss: 0.0011249924786388874
# Running on device :  cuda
# Epoch: 273, Batch: 100, Avg. Loss: 0.0012641206025145947
# Running on device :  cuda
# Epoch: 274, Batch: 100, Avg. Loss: 0.0011579039427451789
# Running on device :  cuda
# Epoch: 275, Batch: 100, Avg. Loss: 0.0011881712917238474
# Running on device :  cuda
# Epoch: 276, Batch: 100, Avg. Loss: 0.0012334537841379642
# Running on device :  cuda
# Epoch: 277, Batch: 100, Avg. Loss: 0.0012143821977078915
# Running on device :  cuda
# Epoch: 278, Batch: 100, Avg. Loss: 0.0011278780330903828
# Running on device :  cuda
# Epoch: 279, Batch: 100, Avg. Loss: 0.0010756198675371707
# Running on device :  cuda
# Epoch: 280, Batch: 100, Avg. Loss: 0.0012384344446472824
# Running on device :  cuda
# Epoch: 281, Batch: 100, Avg. Loss: 0.0011113222669810058
# Running on device :  cuda
# Epoch: 282, Batch: 100, Avg. Loss: 0.0011724711977876723
# Running on device :  cuda
# Epoch: 283, Batch: 100, Avg. Loss: 0.0012060921699739993
# Running on device :  cuda
# Epoch: 284, Batch: 100, Avg. Loss: 0.0010876397606916725
# Running on device :  cuda
# Epoch: 285, Batch: 100, Avg. Loss: 0.0011431908668018877
# Running on device :  cuda
# Epoch: 286, Batch: 100, Avg. Loss: 0.001191587028093636
# Running on device :  cuda
# Epoch: 287, Batch: 100, Avg. Loss: 0.001166895832400769
# Running on device :  cuda
# Epoch: 288, Batch: 100, Avg. Loss: 0.0010557905812747777
# Running on device :  cuda
# Epoch: 289, Batch: 100, Avg. Loss: 0.0011673518880270422
# Running on device :  cuda
# Epoch: 290, Batch: 100, Avg. Loss: 0.001118347784038633
# Running on device :  cuda
# Epoch: 291, Batch: 100, Avg. Loss: 0.001095257420092821
# Running on device :  cuda
# Epoch: 292, Batch: 100, Avg. Loss: 0.0010570430224761368
# Running on device :  cuda
# Epoch: 293, Batch: 100, Avg. Loss: 0.0010718844113871454
# Running on device :  cuda
# Epoch: 294, Batch: 100, Avg. Loss: 0.0010850790641270577
# Running on device :  cuda
# Epoch: 295, Batch: 100, Avg. Loss: 0.0010878156879916786
# Running on device :  cuda
# Epoch: 296, Batch: 100, Avg. Loss: 0.0011598166306503116
# Running on device :  cuda
# Epoch: 297, Batch: 100, Avg. Loss: 0.0010984534467570483
# Running on device :  cuda
# Epoch: 298, Batch: 100, Avg. Loss: 0.0010949395885691048
# Running on device :  cuda
# Epoch: 299, Batch: 100, Avg. Loss: 0.0011136828558519483
# Running on device :  cuda
# Epoch: 300, Batch: 100, Avg. Loss: 0.0011780792814679443
# Running on device :  cuda
# Epoch: 301, Batch: 100, Avg. Loss: 0.0011074694660492242
# Running on device :  cuda
# Epoch: 302, Batch: 100, Avg. Loss: 0.0010652281139045953
# Running on device :  cuda
# Epoch: 303, Batch: 100, Avg. Loss: 0.0011666595241986216
# Running on device :  cuda
# Epoch: 304, Batch: 100, Avg. Loss: 0.0011819227174855768
# Running on device :  cuda
# Epoch: 305, Batch: 100, Avg. Loss: 0.0011321399766020476
# Running on device :  cuda
# Epoch: 306, Batch: 100, Avg. Loss: 0.0011407168176956475
# Running on device :  cuda
# Epoch: 307, Batch: 100, Avg. Loss: 0.0010605243309400976
# Running on device :  cuda
# Epoch: 308, Batch: 100, Avg. Loss: 0.0011862878408282996
# Running on device :  cuda
# Epoch: 309, Batch: 100, Avg. Loss: 0.00109902595449239
# Running on device :  cuda
# Epoch: 310, Batch: 100, Avg. Loss: 0.0010764723089523613
# Running on device :  cuda
# Epoch: 311, Batch: 100, Avg. Loss: 0.001118382150772959
# Running on device :  cuda
# Epoch: 312, Batch: 100, Avg. Loss: 0.0011308922171592713
# Running on device :  cuda
# Epoch: 313, Batch: 100, Avg. Loss: 0.0010918900342658162
# Running on device :  cuda
# Epoch: 314, Batch: 100, Avg. Loss: 0.0009998158565722407
# Running on device :  cuda
# Epoch: 315, Batch: 100, Avg. Loss: 0.0010876191202551127
# Running on device :  cuda
# Epoch: 316, Batch: 100, Avg. Loss: 0.0010840697744861245
# Running on device :  cuda
# Epoch: 317, Batch: 100, Avg. Loss: 0.0010645110975019633
# Running on device :  cuda
# Epoch: 318, Batch: 100, Avg. Loss: 0.0010325997984036803
# Running on device :  cuda
# Epoch: 319, Batch: 100, Avg. Loss: 0.0011328445109538734
# Running on device :  cuda
# Epoch: 320, Batch: 100, Avg. Loss: 0.001098796452395618
# Running on device :  cuda
# Epoch: 321, Batch: 100, Avg. Loss: 0.00104099496640265
# Running on device :  cuda
# Epoch: 322, Batch: 100, Avg. Loss: 0.0009975016321986914
# Running on device :  cuda
# Epoch: 323, Batch: 100, Avg. Loss: 0.0011527121393010021
# Running on device :  cuda
# Epoch: 324, Batch: 100, Avg. Loss: 0.0010245667472481728
# Running on device :  cuda
# Epoch: 325, Batch: 100, Avg. Loss: 0.001108215871732682
# Running on device :  cuda
# Epoch: 326, Batch: 100, Avg. Loss: 0.0010256080008111893
# Running on device :  cuda
# Epoch: 327, Batch: 100, Avg. Loss: 0.001089393530972302
# Running on device :  cuda
# Epoch: 328, Batch: 100, Avg. Loss: 0.001150737043004483
# Running on device :  cuda
# Epoch: 329, Batch: 100, Avg. Loss: 0.0010469679478555918
# Running on device :  cuda
# Epoch: 330, Batch: 100, Avg. Loss: 0.001011458208784461
# Running on device :  cuda
# Epoch: 331, Batch: 100, Avg. Loss: 0.0010421625641174614
# Running on device :  cuda
# Epoch: 332, Batch: 100, Avg. Loss: 0.00104429464135319
# Running on device :  cuda
# Epoch: 333, Batch: 100, Avg. Loss: 0.0009609914682805538
# Running on device :  cuda
# Epoch: 334, Batch: 100, Avg. Loss: 0.0010062258010730147
# Running on device :  cuda
# Epoch: 335, Batch: 100, Avg. Loss: 0.001021893508732319
# Running on device :  cuda
# Epoch: 336, Batch: 100, Avg. Loss: 0.0009870442543178798
# Running on device :  cuda
# Epoch: 337, Batch: 100, Avg. Loss: 0.001024656374938786
# Running on device :  cuda
# Epoch: 338, Batch: 100, Avg. Loss: 0.0010760790924541652
# Running on device :  cuda
# Epoch: 339, Batch: 100, Avg. Loss: 0.0011411886848509312
# Running on device :  cuda
# Epoch: 340, Batch: 100, Avg. Loss: 0.001053692507557571
# Running on device :  cuda
# Epoch: 341, Batch: 100, Avg. Loss: 0.0010734972367063165
# Running on device :  cuda
# Epoch: 342, Batch: 100, Avg. Loss: 0.0010418621744029224
# Running on device :  cuda
# Epoch: 343, Batch: 100, Avg. Loss: 0.0010065090721473099
# Running on device :  cuda
# Epoch: 344, Batch: 100, Avg. Loss: 0.0010253038336522878
# Running on device :  cuda
# Epoch: 345, Batch: 100, Avg. Loss: 0.0010204005921259523
# Running on device :  cuda
# Epoch: 346, Batch: 100, Avg. Loss: 0.0009542602286674082
# Running on device :  cuda
# Epoch: 347, Batch: 100, Avg. Loss: 0.0010752767468802632
# Running on device :  cuda
# Epoch: 348, Batch: 100, Avg. Loss: 0.0010634638057090342
# Running on device :  cuda
# Epoch: 349, Batch: 100, Avg. Loss: 0.0010515480320900678
# Running on device :  cuda
# Epoch: 350, Batch: 100, Avg. Loss: 0.000971971551887691
# Running on device :  cuda
# Epoch: 351, Batch: 100, Avg. Loss: 0.0010161554268561304
# Running on device :  cuda
# Epoch: 352, Batch: 100, Avg. Loss: 0.0009716226886957883
# Running on device :  cuda
# Epoch: 353, Batch: 100, Avg. Loss: 0.001109210922382772
# Running on device :  cuda
# Epoch: 354, Batch: 100, Avg. Loss: 0.0009752914435230195
# Running on device :  cuda
# Epoch: 355, Batch: 100, Avg. Loss: 0.0010022095767781138
# Running on device :  cuda
# Epoch: 356, Batch: 100, Avg. Loss: 0.0009778631110675634
# Running on device :  cuda
# Epoch: 357, Batch: 100, Avg. Loss: 0.0010422383788973094
# Running on device :  cuda
# Epoch: 358, Batch: 100, Avg. Loss: 0.0010325331832282245
# Running on device :  cuda
# Epoch: 359, Batch: 100, Avg. Loss: 0.0009703105268999934
# Running on device :  cuda
# Epoch: 360, Batch: 100, Avg. Loss: 0.0010089642144739627
# Running on device :  cuda
# Epoch: 361, Batch: 100, Avg. Loss: 0.001006931924726814
# Running on device :  cuda
# Epoch: 362, Batch: 100, Avg. Loss: 0.0010285459896549583
# Running on device :  cuda
# Epoch: 363, Batch: 100, Avg. Loss: 0.0009765025549568236
# Running on device :  cuda
# Epoch: 364, Batch: 100, Avg. Loss: 0.0010416703363880515
# Running on device :  cuda
# Epoch: 365, Batch: 100, Avg. Loss: 0.00104931958951056
# Running on device :  cuda
# Epoch: 366, Batch: 100, Avg. Loss: 0.000929968895856291
# Running on device :  cuda
# Epoch: 367, Batch: 100, Avg. Loss: 0.0010126992939040065
# Running on device :  cuda
# Epoch: 368, Batch: 100, Avg. Loss: 0.0010706954430788754
# Running on device :  cuda
# Epoch: 369, Batch: 100, Avg. Loss: 0.0011484440793283284
# Running on device :  cuda
# Epoch: 370, Batch: 100, Avg. Loss: 0.0010291360062547029
# Running on device :  cuda
# Epoch: 371, Batch: 100, Avg. Loss: 0.001037426189519465
# Running on device :  cuda
# Epoch: 372, Batch: 100, Avg. Loss: 0.001073774218559265
# Running on device :  cuda
# Epoch: 373, Batch: 100, Avg. Loss: 0.0010156405698508023
# Running on device :  cuda
# Epoch: 374, Batch: 100, Avg. Loss: 0.001113722175359726
# Running on device :  cuda
# Epoch: 375, Batch: 100, Avg. Loss: 0.0009953078636899591
# Running on device :  cuda
# Epoch: 376, Batch: 100, Avg. Loss: 0.0009502370432019234
# Running on device :  cuda
# Epoch: 377, Batch: 100, Avg. Loss: 0.0009687182707712054
# Running on device :  cuda
# Epoch: 378, Batch: 100, Avg. Loss: 0.0010620562038384377
# Running on device :  cuda
# Epoch: 379, Batch: 100, Avg. Loss: 0.0009728623856790364
# Running on device :  cuda
# Epoch: 380, Batch: 100, Avg. Loss: 0.0009415422324091196
# Running on device :  cuda
# Epoch: 381, Batch: 100, Avg. Loss: 0.0009451890210621059
# Running on device :  cuda
# Epoch: 382, Batch: 100, Avg. Loss: 0.0009933957997709513
# Running on device :  cuda
# Epoch: 383, Batch: 100, Avg. Loss: 0.0009747904082760215
# Running on device :  cuda
# Epoch: 384, Batch: 100, Avg. Loss: 0.0009302329570055008
# Running on device :  cuda
# Epoch: 385, Batch: 100, Avg. Loss: 0.000969281115103513
# Running on device :  cuda
# Epoch: 386, Batch: 100, Avg. Loss: 0.0009527305313386023
# Running on device :  cuda
# Epoch: 387, Batch: 100, Avg. Loss: 0.001012002343777567
# Running on device :  cuda
# Epoch: 388, Batch: 100, Avg. Loss: 0.0009586488427594304
# Running on device :  cuda
# Epoch: 389, Batch: 100, Avg. Loss: 0.0010208599492907524
# Running on device :  cuda
# Epoch: 390, Batch: 100, Avg. Loss: 0.0010160737563855945
# Running on device :  cuda
# Epoch: 391, Batch: 100, Avg. Loss: 0.0009793936861678958
# Running on device :  cuda
# Epoch: 392, Batch: 100, Avg. Loss: 0.0009891887102276087
# Running on device :  cuda
# Epoch: 393, Batch: 100, Avg. Loss: 0.000968052747193724
# Running on device :  cuda
# Epoch: 394, Batch: 100, Avg. Loss: 0.0010593816773034632
# Running on device :  cuda
# Epoch: 395, Batch: 100, Avg. Loss: 0.0010007187933661044
# Running on device :  cuda
# Epoch: 396, Batch: 100, Avg. Loss: 0.0009909394071437418
# Running on device :  cuda
# Epoch: 397, Batch: 100, Avg. Loss: 0.0010649910429492593
# Running on device :  cuda
# Epoch: 398, Batch: 100, Avg. Loss: 0.0009734883191995323
# Running on device :  cuda
# Epoch: 399, Batch: 100, Avg. Loss: 0.0010144012202508747
# Running on device :  cuda
# Epoch: 400, Batch: 100, Avg. Loss: 0.0009848035010509193
# Running on device :  cuda
# Epoch: 401, Batch: 100, Avg. Loss: 0.0010096734170801937
# Running on device :  cuda
# Epoch: 402, Batch: 100, Avg. Loss: 0.0009799807234667241
# Running on device :  cuda
# Epoch: 403, Batch: 100, Avg. Loss: 0.0009316827426664532
# Running on device :  cuda
# Epoch: 404, Batch: 100, Avg. Loss: 0.0009347497071139514
# Running on device :  cuda
# Epoch: 405, Batch: 100, Avg. Loss: 0.0010569811556488276
# Running on device :  cuda
# Epoch: 406, Batch: 100, Avg. Loss: 0.0009387904480099678
# Running on device :  cuda
# Epoch: 407, Batch: 100, Avg. Loss: 0.0009210667726583779
# Running on device :  cuda
# Epoch: 408, Batch: 100, Avg. Loss: 0.0009251202493906021
# Running on device :  cuda
# Epoch: 409, Batch: 100, Avg. Loss: 0.0009652006546966731
# Running on device :  cuda
# Epoch: 410, Batch: 100, Avg. Loss: 0.0009312369194813073
# Running on device :  cuda
# Epoch: 411, Batch: 100, Avg. Loss: 0.0009816117556765676
# Running on device :  cuda
# Epoch: 412, Batch: 100, Avg. Loss: 0.0009871675805188716
# Running on device :  cuda
# Epoch: 413, Batch: 100, Avg. Loss: 0.0009806966483592986
# Running on device :  cuda
# Epoch: 414, Batch: 100, Avg. Loss: 0.0009565319740213454
# Running on device :  cuda
# Epoch: 415, Batch: 100, Avg. Loss: 0.0009158866237848997
# Running on device :  cuda
# Epoch: 416, Batch: 100, Avg. Loss: 0.0009790116832591592
# Running on device :  cuda
# Epoch: 417, Batch: 100, Avg. Loss: 0.0009367736275307834
# Running on device :  cuda
# Epoch: 418, Batch: 100, Avg. Loss: 0.0009589485945180058
# Running on device :  cuda
# Epoch: 419, Batch: 100, Avg. Loss: 0.0010238517462275922
# Running on device :  cuda
# Epoch: 420, Batch: 100, Avg. Loss: 0.0010475889914669096
# Running on device :  cuda
# Epoch: 421, Batch: 100, Avg. Loss: 0.0009772282298654317
# Running on device :  cuda
# Epoch: 422, Batch: 100, Avg. Loss: 0.001028477223124355
# Running on device :  cuda
# Epoch: 423, Batch: 100, Avg. Loss: 0.0009745490336790681
# Running on device :  cuda
# Epoch: 424, Batch: 100, Avg. Loss: 0.0009773670258000492
# Running on device :  cuda
# Epoch: 425, Batch: 100, Avg. Loss: 0.0008504284927621483
# Running on device :  cuda
# Epoch: 426, Batch: 100, Avg. Loss: 0.0009852544185705483
# Running on device :  cuda
# Epoch: 427, Batch: 100, Avg. Loss: 0.0009280461673624814
# Running on device :  cuda
# Epoch: 428, Batch: 100, Avg. Loss: 0.0009304536744020879
# Running on device :  cuda
# Epoch: 429, Batch: 100, Avg. Loss: 0.0009318280755542218
# Running on device :  cuda
# Epoch: 430, Batch: 100, Avg. Loss: 0.000927880453877151
# Running on device :  cuda
# Epoch: 431, Batch: 100, Avg. Loss: 0.0009319631946273148
# Running on device :  cuda
# Epoch: 432, Batch: 100, Avg. Loss: 0.0008814265164546668
# Running on device :  cuda
# Epoch: 433, Batch: 100, Avg. Loss: 0.0009398578247055412
# Running on device :  cuda
# Epoch: 434, Batch: 100, Avg. Loss: 0.0009370147092267871
# Running on device :  cuda
# Epoch: 435, Batch: 100, Avg. Loss: 0.0009261483638547361
# Running on device :  cuda
# Epoch: 436, Batch: 100, Avg. Loss: 0.0009859338109381498
# Running on device :  cuda
# Epoch: 437, Batch: 100, Avg. Loss: 0.0009486639746464788
# Running on device :  cuda
# Epoch: 438, Batch: 100, Avg. Loss: 0.0009326028279028833
# Running on device :  cuda
# Epoch: 439, Batch: 100, Avg. Loss: 0.0009376228558830917
# Running on device :  cuda
# Epoch: 440, Batch: 100, Avg. Loss: 0.0009126753942109645
# Running on device :  cuda
# Epoch: 441, Batch: 100, Avg. Loss: 0.0009386209920048714
# Running on device :  cuda
# Epoch: 442, Batch: 100, Avg. Loss: 0.0009511128412559628
# Running on device :  cuda
# Epoch: 443, Batch: 100, Avg. Loss: 0.0008522953866049647
# Running on device :  cuda
# Epoch: 444, Batch: 100, Avg. Loss: 0.0009359322441741824
# Running on device :  cuda
# Epoch: 445, Batch: 100, Avg. Loss: 0.0009178932071663439
# Running on device :  cuda
# Epoch: 446, Batch: 100, Avg. Loss: 0.0009076363383792341
# Running on device :  cuda
# Epoch: 447, Batch: 100, Avg. Loss: 0.0009710550047457218
# Running on device :  cuda
# Epoch: 448, Batch: 100, Avg. Loss: 0.0009829423734918237
# Running on device :  cuda
# Epoch: 449, Batch: 100, Avg. Loss: 0.0008794984766282142
# Running on device :  cuda
# Epoch: 450, Batch: 100, Avg. Loss: 0.0009786545960232616
# Running on device :  cuda
# Epoch: 451, Batch: 100, Avg. Loss: 0.0009705922454595566
# Running on device :  cuda
# Epoch: 452, Batch: 100, Avg. Loss: 0.0008458205559290946
# Running on device :  cuda
# Epoch: 453, Batch: 100, Avg. Loss: 0.0009474407201632857
# Running on device :  cuda
# Epoch: 454, Batch: 100, Avg. Loss: 0.0009007041687145829
# Running on device :  cuda
# Epoch: 455, Batch: 100, Avg. Loss: 0.0009148282138630747
# Running on device :  cuda
# Epoch: 456, Batch: 100, Avg. Loss: 0.000957786432467401
# Running on device :  cuda
# Epoch: 457, Batch: 100, Avg. Loss: 0.0009042745688930154
# Running on device :  cuda
# Epoch: 458, Batch: 100, Avg. Loss: 0.0009423644272610546
# Running on device :  cuda
# Epoch: 459, Batch: 100, Avg. Loss: 0.0009236393230967224
# Running on device :  cuda
# Epoch: 460, Batch: 100, Avg. Loss: 0.0008988732253201306
# Running on device :  cuda
# Epoch: 461, Batch: 100, Avg. Loss: 0.0009300492485053838
# Running on device :  cuda
# Epoch: 462, Batch: 100, Avg. Loss: 0.0009914473835378886
# Running on device :  cuda
# Epoch: 463, Batch: 100, Avg. Loss: 0.0009097731537185609
# Running on device :  cuda
# Epoch: 464, Batch: 100, Avg. Loss: 0.0009603058504872024
# Running on device :  cuda
# Epoch: 465, Batch: 100, Avg. Loss: 0.0008797766747884453
# Running on device :  cuda
# Epoch: 466, Batch: 100, Avg. Loss: 0.000963682668749243
# Running on device :  cuda
# Epoch: 467, Batch: 100, Avg. Loss: 0.0009663530397228897
# Running on device :  cuda
# Epoch: 468, Batch: 100, Avg. Loss: 0.0009253545487299562
# Running on device :  cuda
# Epoch: 469, Batch: 100, Avg. Loss: 0.0008719278108328581
# Running on device :  cuda
# Epoch: 470, Batch: 100, Avg. Loss: 0.000913187047932297
# Running on device :  cuda
# Epoch: 471, Batch: 100, Avg. Loss: 0.0008777376557700336
# Running on device :  cuda
# Epoch: 472, Batch: 100, Avg. Loss: 0.0008934263028204441
# Running on device :  cuda
# Epoch: 473, Batch: 100, Avg. Loss: 0.0008621999705210328
# Running on device :  cuda
# Epoch: 474, Batch: 100, Avg. Loss: 0.0009311330700293183
# Running on device :  cuda
# Epoch: 475, Batch: 100, Avg. Loss: 0.0008820608356036245
# Running on device :  cuda
# Epoch: 476, Batch: 100, Avg. Loss: 0.0008991922433488071
# Running on device :  cuda
# Epoch: 477, Batch: 100, Avg. Loss: 0.0009331725141964853
# Running on device :  cuda
# Epoch: 478, Batch: 100, Avg. Loss: 0.0009558723960071803
# Running on device :  cuda
# Epoch: 479, Batch: 100, Avg. Loss: 0.0009486296405084431
# Running on device :  cuda
# Epoch: 480, Batch: 100, Avg. Loss: 0.000927845036610961
# Running on device :  cuda
# Epoch: 481, Batch: 100, Avg. Loss: 0.0009391004373319448
# Running on device :  cuda
# Epoch: 482, Batch: 100, Avg. Loss: 0.0008863923777826131
# Running on device :  cuda
# Epoch: 483, Batch: 100, Avg. Loss: 0.0009188661575317383
# Running on device :  cuda
# Epoch: 484, Batch: 100, Avg. Loss: 0.0008925734297372401
# Running on device :  cuda
# Epoch: 485, Batch: 100, Avg. Loss: 0.0008819077261723578
# Running on device :  cuda
# Epoch: 486, Batch: 100, Avg. Loss: 0.0009364133309572936
# Running on device :  cuda
# Epoch: 487, Batch: 100, Avg. Loss: 0.0008882437138818205
# Running on device :  cuda
# Epoch: 488, Batch: 100, Avg. Loss: 0.0008578520757146179
# Running on device :  cuda
# Epoch: 489, Batch: 100, Avg. Loss: 0.0008911966611631215
# Running on device :  cuda
# Epoch: 490, Batch: 100, Avg. Loss: 0.0008928729090839625
# Running on device :  cuda
# Epoch: 491, Batch: 100, Avg. Loss: 0.0009218258005566895
# Running on device :  cuda
# Epoch: 492, Batch: 100, Avg. Loss: 0.0008866575355641543
# Running on device :  cuda
# Epoch: 493, Batch: 100, Avg. Loss: 0.0008635381357744336
# Running on device :  cuda
# Epoch: 494, Batch: 100, Avg. Loss: 0.0008933273176662624
# Running on device :  cuda
# Epoch: 495, Batch: 100, Avg. Loss: 0.0008482871800661087
# Running on device :  cuda
# Epoch: 496, Batch: 100, Avg. Loss: 0.0009364071888849139
# Running on device :  cuda
# Epoch: 497, Batch: 100, Avg. Loss: 0.0009110763184726238
# Running on device :  cuda
# Epoch: 498, Batch: 100, Avg. Loss: 0.000818604703526944
# Running on device :  cuda
# Epoch: 499, Batch: 100, Avg. Loss: 0.0008944936729967595
# Running on device :  cuda
# Epoch: 500, Batch: 100, Avg. Loss: 0.0008883345620706677
# Running on device :  cuda
# Epoch: 501, Batch: 100, Avg. Loss: 0.0009089814824983478
# Running on device :  cuda
# Epoch: 502, Batch: 100, Avg. Loss: 0.000976534842979163
# Running on device :  cuda
# Epoch: 503, Batch: 100, Avg. Loss: 0.000905692532658577
# Running on device :  cuda
# Epoch: 504, Batch: 100, Avg. Loss: 0.0008593344637192786
# Running on device :  cuda
# Epoch: 505, Batch: 100, Avg. Loss: 0.0008046259540133178
# Running on device :  cuda
# Epoch: 506, Batch: 100, Avg. Loss: 0.0008819527793675661
# Running on device :  cuda
# Epoch: 507, Batch: 100, Avg. Loss: 0.0009260132960043848
# Running on device :  cuda
# Epoch: 508, Batch: 100, Avg. Loss: 0.0009074110817164182
# Running on device :  cuda
# Epoch: 509, Batch: 100, Avg. Loss: 0.0008651851746253669
# Running on device :  cuda
# Epoch: 510, Batch: 100, Avg. Loss: 0.000878504300955683
# Running on device :  cuda
# Epoch: 511, Batch: 100, Avg. Loss: 0.000862000145483762
# Running on device :  cuda
# Epoch: 512, Batch: 100, Avg. Loss: 0.0008873141459189355
# Running on device :  cuda
# Epoch: 513, Batch: 100, Avg. Loss: 0.0008307236577384173
# Running on device :  cuda
# Epoch: 514, Batch: 100, Avg. Loss: 0.0008866223101504147
# Running on device :  cuda
# Epoch: 515, Batch: 100, Avg. Loss: 0.0008953111744485796
# Running on device :  cuda
# Epoch: 516, Batch: 100, Avg. Loss: 0.0009304339168593287
# Running on device :  cuda
# Epoch: 517, Batch: 100, Avg. Loss: 0.0008372876662760973
# Running on device :  cuda
# Epoch: 518, Batch: 100, Avg. Loss: 0.0008552092704921961
# Running on device :  cuda
# Epoch: 519, Batch: 100, Avg. Loss: 0.0009514916036278009
# Running on device :  cuda
# Epoch: 520, Batch: 100, Avg. Loss: 0.000870294941123575
# Running on device :  cuda
# Epoch: 521, Batch: 100, Avg. Loss: 0.0008525320501066745
# Running on device :  cuda
# Epoch: 522, Batch: 100, Avg. Loss: 0.0008777061295695603
# Running on device :  cuda
# Epoch: 523, Batch: 100, Avg. Loss: 0.0009010090660303831
# Running on device :  cuda
# Epoch: 524, Batch: 100, Avg. Loss: 0.0008926613158546388
# Running on device :  cuda
# Epoch: 525, Batch: 100, Avg. Loss: 0.000824571380391717
# Running on device :  cuda
# Epoch: 526, Batch: 100, Avg. Loss: 0.0008519865875132381
# Running on device :  cuda
# Epoch: 527, Batch: 100, Avg. Loss: 0.0008482238994911313
# Running on device :  cuda
# Epoch: 528, Batch: 100, Avg. Loss: 0.0008983137891627848
# Running on device :  cuda
# Epoch: 529, Batch: 100, Avg. Loss: 0.000874047068413347
# Running on device :  cuda
# Epoch: 530, Batch: 100, Avg. Loss: 0.000894235239829868
# Running on device :  cuda
# Epoch: 531, Batch: 100, Avg. Loss: 0.0007847547377459705
# Running on device :  cuda
# Epoch: 532, Batch: 100, Avg. Loss: 0.0008451875317841769
# Running on device :  cuda
# Epoch: 533, Batch: 100, Avg. Loss: 0.0009084377749823034
# Running on device :  cuda
# Epoch: 534, Batch: 100, Avg. Loss: 0.0007965647969394922
# Running on device :  cuda
# Epoch: 535, Batch: 100, Avg. Loss: 0.0009521229038946331
# Running on device :  cuda
# Epoch: 536, Batch: 100, Avg. Loss: 0.0008593920511193574
# Running on device :  cuda
# Epoch: 537, Batch: 100, Avg. Loss: 0.0008578156121075153
# Running on device :  cuda
# Epoch: 538, Batch: 100, Avg. Loss: 0.0009069243525154888
# Running on device :  cuda
# Epoch: 539, Batch: 100, Avg. Loss: 0.0008557575149461627
# Running on device :  cuda
# Epoch: 540, Batch: 100, Avg. Loss: 0.0009369284175336361
# Running on device :  cuda
# Epoch: 541, Batch: 100, Avg. Loss: 0.0008260869346559047
# Running on device :  cuda
# Epoch: 542, Batch: 100, Avg. Loss: 0.0008298549992032349
# Running on device :  cuda
# Epoch: 543, Batch: 100, Avg. Loss: 0.0008799793715588748
# Running on device :  cuda
# Epoch: 544, Batch: 100, Avg. Loss: 0.0008131372318603098
# Running on device :  cuda
# Epoch: 545, Batch: 100, Avg. Loss: 0.0008040325497277081
# Running on device :  cuda
# Epoch: 546, Batch: 100, Avg. Loss: 0.000830735492054373
# Running on device :  cuda
# Epoch: 547, Batch: 100, Avg. Loss: 0.0008416866930201649
# Running on device :  cuda
# Epoch: 548, Batch: 100, Avg. Loss: 0.0008342681690119207
# Running on device :  cuda
# Epoch: 549, Batch: 100, Avg. Loss: 0.0008335257209837436
# Running on device :  cuda
# Epoch: 550, Batch: 100, Avg. Loss: 0.0008090620920993387
# Running on device :  cuda
# Epoch: 551, Batch: 100, Avg. Loss: 0.0008134889234788716
# Running on device :  cuda
# Epoch: 552, Batch: 100, Avg. Loss: 0.0008358646845445037
# Running on device :  cuda
# Epoch: 553, Batch: 100, Avg. Loss: 0.0008540079174563288
# Running on device :  cuda
# Epoch: 554, Batch: 100, Avg. Loss: 0.0009305763375014067
# Running on device :  cuda
# Epoch: 555, Batch: 100, Avg. Loss: 0.0008558954964391888
# Running on device :  cuda
# Epoch: 556, Batch: 100, Avg. Loss: 0.0008132469919510186
# Running on device :  cuda
# Epoch: 557, Batch: 100, Avg. Loss: 0.0008333651791326702
# Running on device :  cuda
# Epoch: 558, Batch: 100, Avg. Loss: 0.0008288262910209596
# Running on device :  cuda
# Epoch: 559, Batch: 100, Avg. Loss: 0.0008448159410618246
# Running on device :  cuda
# Epoch: 560, Batch: 100, Avg. Loss: 0.0008266689912416041
# Running on device :  cuda
# Epoch: 561, Batch: 100, Avg. Loss: 0.0008187313596718013
# Running on device :  cuda
# Epoch: 562, Batch: 100, Avg. Loss: 0.0008245579120703041
# Running on device :  cuda
# Epoch: 563, Batch: 100, Avg. Loss: 0.0008370975339785219
# Running on device :  cuda
# Epoch: 564, Batch: 100, Avg. Loss: 0.0008425777098163963
# Running on device :  cuda
# Epoch: 565, Batch: 100, Avg. Loss: 0.0008250123024918139
# Running on device :  cuda
# Epoch: 566, Batch: 100, Avg. Loss: 0.0008538336805067957
# Running on device :  cuda
# Epoch: 567, Batch: 100, Avg. Loss: 0.000815290478989482
# Running on device :  cuda
# Epoch: 568, Batch: 100, Avg. Loss: 0.0008355566933751106
# Running on device :  cuda
# Epoch: 569, Batch: 100, Avg. Loss: 0.0008275792659260333
# Running on device :  cuda
# Epoch: 570, Batch: 100, Avg. Loss: 0.0008540382641367614
# Running on device :  cuda
# Epoch: 571, Batch: 100, Avg. Loss: 0.0008292005457915365
# Running on device :  cuda
# Epoch: 572, Batch: 100, Avg. Loss: 0.0008910235790535808
# Running on device :  cuda
# Epoch: 573, Batch: 100, Avg. Loss: 0.0008816024637781084
# Running on device :  cuda
# Epoch: 574, Batch: 100, Avg. Loss: 0.0007729359213262797
# Running on device :  cuda
# Epoch: 575, Batch: 100, Avg. Loss: 0.000815126467961818
# Running on device :  cuda
# Epoch: 576, Batch: 100, Avg. Loss: 0.0008727069194428622
# Running on device :  cuda
# Epoch: 577, Batch: 100, Avg. Loss: 0.0008620054409839213
# Running on device :  cuda
# Epoch: 578, Batch: 100, Avg. Loss: 0.0008684591683559119
# Running on device :  cuda
# Epoch: 579, Batch: 100, Avg. Loss: 0.000879769675899297
# Running on device :  cuda
# Epoch: 580, Batch: 100, Avg. Loss: 0.0007830985803157091
# Running on device :  cuda
# Epoch: 581, Batch: 100, Avg. Loss: 0.00087428616033867
# Running on device :  cuda
# Epoch: 582, Batch: 100, Avg. Loss: 0.0007921555172652006
# Running on device :  cuda
# Epoch: 583, Batch: 100, Avg. Loss: 0.0008536097826436162
# Running on device :  cuda
# Epoch: 584, Batch: 100, Avg. Loss: 0.0008002366721630097
# Running on device :  cuda
# Epoch: 585, Batch: 100, Avg. Loss: 0.0008736568591557443
# Running on device :  cuda
# Epoch: 586, Batch: 100, Avg. Loss: 0.0008384722485207021
# Running on device :  cuda
# Epoch: 587, Batch: 100, Avg. Loss: 0.0008272667848505079
# Running on device :  cuda
# Epoch: 588, Batch: 100, Avg. Loss: 0.0008014582488685846
# Running on device :  cuda
# Epoch: 589, Batch: 100, Avg. Loss: 0.0008013606648892165
# Running on device :  cuda
# Epoch: 590, Batch: 100, Avg. Loss: 0.000800596287008375
# Running on device :  cuda
# Epoch: 591, Batch: 100, Avg. Loss: 0.0008753524390049279
# Running on device :  cuda
# Epoch: 592, Batch: 100, Avg. Loss: 0.0009385535512119532
# Running on device :  cuda
# Epoch: 593, Batch: 100, Avg. Loss: 0.0008370031011290848
# Running on device :  cuda
# Epoch: 594, Batch: 100, Avg. Loss: 0.0009188704057596624
# Running on device :  cuda
# Epoch: 595, Batch: 100, Avg. Loss: 0.0008127337447367608
# Running on device :  cuda
# Epoch: 596, Batch: 100, Avg. Loss: 0.0008166855643503368
# Running on device :  cuda
# Epoch: 597, Batch: 100, Avg. Loss: 0.0007980041671544313
# Running on device :  cuda
# Epoch: 598, Batch: 100, Avg. Loss: 0.0008588886824436486
# Running on device :  cuda
# Epoch: 599, Batch: 100, Avg. Loss: 0.0007803735076449812
# Running on device :  cuda
# Epoch: 600, Batch: 100, Avg. Loss: 0.000929568043909967
# Finished Training
# Training Accuracy (MSE):  2.35908468389

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())

print("\nAccuracy(MSE): ", accuracy_mse(test_outputs, gt_pts))
# Out:
# net_sample
#
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])
#
# Accuracy(MSE):  2.79022024374

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**:
# I chose SmoothL1Loss as the loss function. We need to compare the predicted values with the target values directly, therefore we can't use CrossEntropy (which is for classification problem).
#
# I first started with MSELoss, since we are prdicting points on a image, it makes sense to evaluate the results by calculating the Euclidean distance between the ground truth and predicted points. MSE is similar as Euclidean distance hence my choice. Besides, during training, MSE (or L2 loss) is more stable than L1 loss when error becomes small.
#
# Then I started to explore SmoothL1Loss. I read that Smooth L1-loss combines the advantages of L1-loss (steady gradients for large values of 𝑥, less sensitive to outliers) and L2-loss (less oscillations during updates when 𝑥 is small). And I found that I can achived smaller training loss by using SmoothL1Loss.
#
# For optimization I chose Adam since Adam gives better performance than SGD during training.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: I started the network architecture the same as the FasionMNIST solution notebook, and and chaneged the loss function to MSE. I got a relatively large loss after several epoches of training, and I knew this was highly likely to be under-fitting since the network was too small.
#
# I thought it might be a good ideas to get the network over-fitting first, then reducing latyers/filters to the right size. Hence I started adding more filters and more convolutional layers, and more dense fully connected layers, but soon I found it was too slow to train. Finnaly I refer to [this paper](https://arxiv.org/pdf/1710.00977.pdf) as suggested in the beginning of this notebook, and settles at 5 convolutional layers.
#
# After I got a satifactory training accuracy I found that my model did not perform well on test dataset, I believed this was a strong sign of overfitting hence I addin dropout layers after each conv/fc layers (except for the last layer)

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: batch_size: I read that samll batch_size may introduce some noises (since noises are generally averaged out by using larger batch_size), and large batch_size usually provies more accurate gradients during back-propogate. I know there is some techniques to calculate optimal bacth_size based on network size and GPU memory but in this project I just manually test them and I found batch_size of 32 gave a nice result, while batch_size of 64 uasually causes a memory issue.
#
# For number of epochs, I found the loss did not decrease anymore around 250 cycles hence I just set it to  be 300. I think usually the higher the better, but it also depends on the errors since sometimes more taining doesn't really help reducing the loss.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 1

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[ 0.20209858  0.13651024  0.19403671 -0.05245176 -0.17367864]
#  [-0.09741358 -0.08156125 -0.14881615  0.17388849 -0.16132559]
#  [ 0.05698149  0.18194056  0.03495014 -0.12599769 -0.03405805]
#  [-0.08140615 -0.04271185  0.14358462 -0.18693194  0.10579695]
#  [ 0.18111449 -0.1314788  -0.07969577 -0.04768017  0.00303707]]
# (5, 5)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset
import cv2
number = 100
sample = test_dataset[number]
image = sample['image']

# un-transform the image data
image = image.data   # get the image from it's wrapper
image = image.cpu().numpy()   # convert to numpy array from a Tensor
image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
plt.figure(figsize=(12,6))
ax = plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(image), cmap = 'gray')
ax = plt.subplot(1, 2, 2)
filtered_image = cv2.filter2D(image, -1, w[filter_index][0])
plt.imshow(filtered_image, cmap = 'gray')

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**: This 5x5 filter mainly detects lines along vertical direction (looks like not just vertical, but within a range of angles) hence it's a line detector.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
